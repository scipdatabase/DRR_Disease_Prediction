# %%
import os
import re
import pandas as pd
import numpy as np
from tensorflow import keras
import tensorflow as tf

# %%
model_path = r'C:\Users\91999\OneDrive\Desktop\DRR project\general\ViT models\3cls_1R_trained_ViT_E_7_eps_350_bs_32'

# %%
base_path = r'D:\new rs - Copy'

# %%
output_path = r'C:\Users\91999\OneDrive\Desktop\rs trail.xlsx'

# %%
# Define image dimensions and load the model
img_dim = 288

from tensorflow_addons.optimizers import AdamW

# Register the custom object
with tf.keras.utils.custom_object_scope({'AdamW': AdamW}):
    model = tf.keras.models.load_model(model_path)
#model =  tf.keras.models.load_model(model_path)

# %%
# Extract image file paths
image_file_paths = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.endswith((".png", ".PNG", ".jpeg")):  # Add other image extensions if necessary
            image_file_paths.append(os.path.join(root, file))

# %%
# Load test dataset without shuffling to maintain order
test_ds = keras.utils.image_dataset_from_directory(
    base_path,
    image_size=(img_dim, img_dim),
    label_mode='int',
    batch_size=1000,
    shuffle=False  # Ensure no shuffling to keep image file order intact
)
# Out:
# Found 417 files belonging to 3 classes.

# %%
class_names = test_ds.class_names

# %%
resize_and_rescale = keras.Sequential([
  #layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE),
  keras.layers.experimental.preprocessing.Rescaling(1./255)
])

# %%
data_augmentation = keras.Sequential([
    keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    keras.layers.experimental.preprocessing.RandomRotation(0.1),
    #keras.layers.experimental.preprocessing.RandomFlip("vertical"),
])

# %%
# Function to prepare dataset
AUTOTUNE = tf.data.AUTOTUNE
def prepare(ds, augment=False):
    def resize_and_rescale(image, label):
        image = tf.image.resize(image, [img_dim, img_dim])
        image = tf.cast(image, tf.float32) / 255.0
        return image, label
    
    # Apply resizing and rescaling
    ds = ds.map(lambda x, y: (resize_and_rescale(x, y)), num_parallel_calls=AUTOTUNE)
    
    # Apply data augmentation if specified
    if augment:
        data_augmentation = tf.keras.Sequential([
            tf.keras.layers.RandomFlip("horizontal_and_vertical"),
            tf.keras.layers.RandomRotation(0.2)
        ])
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)
        
    # Use buffered prefetching
    return ds.prefetch(buffer_size=AUTOTUNE)

# %%
# Prepare the test dataset
test_ds = prepare(test_ds)

# %%
# Separate the images and labels
ts_image_batch,tr_label_batch = next(iter(test_ds))
ts_image_batch = np.asarray(ts_image_batch)

# %%
preds = model.predict(ts_image_batch)
# Out:
# 14/14 [==============================] - 39s 2s/step

# %%
# Extract predicted class indices and scores
y_pred_3c = []
for i in preds[0]:
    y_pred_3c = np.append(y_pred_3c,np.argmax(i))

y_pred_scores = []
for i in preds[1]:
    y_pred_scores = np.append(y_pred_scores,int(abs(np.round(i,0))))

# %%
actual_classes = [class_names[label] for label in tr_label_batch]
L = ['CONTROL','NON DRR','PATHOGEN']
y_pred_classes = [L[int(label)] for label in y_pred_3c]

# %%
# Extract image file names using regex
#image_file_names = [re.match(file_name_pattern, file_path).group(1) for file_path in image_file_paths[:len(ts_label_batch)]]
image_file_names = [os.path.basename(file_path) for file_path in image_file_paths[:len(ts_image_batch)]]

# %%
print(len(image_file_names), len(y_pred_classes), len(y_pred_scores))
# Out:
# 417 417 417

# %%
image_file_paths = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.endswith((".png", ".jpg", ".jpeg")):  # Add other image extensions if necessary
            image_file_paths.append(os.path.join(root, file))

print("Total images found:", len(image_file_paths))
# Out:
# Total images found: 417

# %%
# Create a DataFrame with Image Name, Predicted Class, Predicted Score, Actual Class
results_df = pd.DataFrame({
    'Folder': actual_classes,
    'Image Name': image_file_names,
    'Predicted Class': y_pred_classes,
    'Predicted Score': y_pred_scores
})

# %%
# Save the DataFrame to an Excel file with a different name

results_df.to_excel(excel_writer=output_path, index=False)

print(f"Results have been saved to {output_path}")


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.precision', 2)
display(results_df)
# Out:
# Results have been saved to C:\Users\91999\OneDrive\Desktop\rs trail.xlsx
#       Folder         Image Name        Predicted Class  Predicted Score
# 0     CONTROL           ICC10236_C.png      NON DRR           3.0
# 1     CONTROL           ICC10334_C.png      NON DRR           3.0
# 2     CONTROL           ICC10375_C.png      NON DRR           3.0
# 3     CONTROL           ICC10382_C.png      NON DRR           3.0
# 4     CONTROL           ICC10384_C.png      NON DRR           3.0
# 5     CONTROL           ICC10394_C.png      NON DRR           3.0
# 6     CONTROL           ICC10465_C.png      NON DRR           2.0
# 7     CONTROL           ICC10538_C.png      NON DRR           3.0
# 8     CONTROL           ICC10549_C.png      NON DRR           3.0
# 9     CONTROL           ICC10556_C.png      NON DRR           3.0
# 10    CONTROL           ICC10563_C.png      NON DRR           3.0
# 11    CONTROL           ICC10616_C.png      NON DRR           3.0
# 12    CONTROL          ICC109668_C.png      NON DRR           2.0
# 13    CONTROL             ICC170_C.png      NON DRR           4.0
# 14    CONTROL             ICC181_C.png      NON DRR           4.0
# 15    CONTROL             ICC182_C.png      NON DRR           3.0
# 16    CONTROL              ICC18_C.png      NON DRR           3.0
# 17    CONTROL             ICC209_C.png      NON DRR           3.0
# 18    CONTROL             ICC216_C.png      NON DRR           3.0
# 19    CONTROL             ICC240_C.png      NON DRR           3.0
# 20    CONTROL             ICC250_C.png      NON DRR           3.0
# 21    CONTROL             ICC253_C.png      NON DRR           4.0
# 22    CONTROL             ICC265_C.png      NON DRR           3.0
# 23    CONTROL             ICC413_C.png      NON DRR           3.0
# 24    CONTROL             ICC454_C.png      NON DRR           3.0
# 25    CONTROL      icc4958_C_part1.png      NON DRR           3.0
# 26    CONTROL             ICC595_C.png      NON DRR           3.0
# 27    CONTROL             ICC599_C.png      NON DRR           3.0
# 28    CONTROL            ICC6480_C.png      NON DRR           4.0
# 29    CONTROL              ICC64_C.png      NON DRR           3.0
# 30    CONTROL            ICC6743_C.png      NON DRR           3.0
# 31    CONTROL            ICC6756_C.png      NON DRR           3.0
# 32    CONTROL            ICC6796_C.png      NON DRR           3.0
# 33    CONTROL            ICC6801_C.png      NON DRR           3.0
# 34    CONTROL            ICC6803_C.png      NON DRR           3.0
# 35    CONTROL            ICC6817_C.png      NON DRR           3.0
# 36    CONTROL            ICC6821_C.png      NON DRR           3.0
# 37    CONTROL            ICC6822_C.png      NON DRR           3.0
# 38    CONTROL            ICC6843_C.png      NON DRR           3.0
# 39    CONTROL            ICC6855_C.png      NON DRR           3.0
# 40    CONTROL            ICC6858_C.png      NON DRR           3.0
# 41    CONTROL            ICC6876_C.png      NON DRR           3.0
# 42    CONTROL            ICC6879_C.png      NON DRR           3.0
# 43    CONTROL            ICC6883_C.png      NON DRR           5.0
# 44    CONTROL              ICC68_C.png      NON DRR           3.0
# 45    CONTROL            ICC6914_C.png      NON DRR           3.0
# 46    CONTROL            ICC6916_C.png      NON DRR           3.0
# 47    CONTROL            ICC9112_C.png      NON DRR           3.0
# 48    CONTROL            ICC9117_C.png      NON DRR           3.0
# 49    CONTROL            ICC9143_C.png      NON DRR           4.0
# 50    CONTROL              ICC91_C.png      NON DRR           4.0
# 51    CONTROL         JG62_c_part1.png      NON DRR           5.0
# 52    CONTROL         L550_C_part1.png      NON DRR           4.0
# 53   PATHOGEN            143_part1.png      NON DRR           4.0
# 54   PATHOGEN            273_part1.png      NON DRR           4.0
# 55   PATHOGEN   ICC10236_DRR_part1.png      NON DRR           5.0
# 56   PATHOGEN   ICC10236_DRR_part2.png      NON DRR           5.0
# 57   PATHOGEN  ICC1023_DRR_1_part1.png      NON DRR           4.0
# 58   PATHOGEN   ICC10334_DRR_part1.png      NON DRR           4.0
# 59   PATHOGEN   ICC10334_DRR_part2.png      NON DRR           4.0
# 60   PATHOGEN   ICC10375_DRR_part1.png      NON DRR           4.0
# 61   PATHOGEN   ICC10375_DRR_part2.png      NON DRR           4.0
# 62   PATHOGEN   ICC10382_DRR_part1.png      NON DRR           4.0
# 63   PATHOGEN   ICC10382_DRR_part2.png      NON DRR           4.0
# 64   PATHOGEN   ICC10384_DRR_part1.png      NON DRR           4.0
# 65   PATHOGEN   ICC10384_DRR_part2.png      NON DRR           5.0
# 66   PATHOGEN   ICC10394_DRR_part1.png      NON DRR           4.0
# 67   PATHOGEN   ICC10394_DRR_part2.png      NON DRR           3.0
# 68   PATHOGEN   ICC10455_DRR_part1.png      NON DRR           4.0
# 69   PATHOGEN   ICC10455_DRR_part2.png      NON DRR           5.0
# 70   PATHOGEN   ICC10465_DRR_part1.png      NON DRR           5.0
# 71   PATHOGEN   ICC10465_DRR_part2.png      NON DRR           5.0
# 72   PATHOGEN   ICC10492_DRR_part1.png      NON DRR           5.0
# 73   PATHOGEN   ICC10492_DRR_part2.png      NON DRR           4.0
# 74   PATHOGEN   ICC10538_DRR_part1.png      NON DRR           5.0
# 75   PATHOGEN   ICC10538_DRR_part2.png      NON DRR           4.0
# 76   PATHOGEN   ICC10556_DRR_part1.png      NON DRR           5.0
# 77   PATHOGEN   ICC10556_DRR_part2.png      NON DRR           5.0
# 78   PATHOGEN   ICC10563_DRR_part1.png      NON DRR           3.0
# 79   PATHOGEN   ICC10563_DRR_part2.png      NON DRR           4.0
# 80   PATHOGEN   ICC10599_DRR_part1.png      NON DRR           5.0
# 81   PATHOGEN   ICC10599_DRR_part2.png      NON DRR           4.0
# 82   PATHOGEN   ICC10616_DRR_part1.png      NON DRR           4.0
# 83   PATHOGEN   ICC10616_DRR_part2.png      NON DRR           4.0
# 84   PATHOGEN         ICC111_part1.png      NON DRR           3.0
# 85   PATHOGEN   ICC11611_DRR_part1.png      NON DRR           4.0
# 86   PATHOGEN      ICC1196.1_part1.png      NON DRR           4.0
# 87   PATHOGEN      ICC1201.1_part1.png      NON DRR           5.0
# 88   PATHOGEN  ICC1202_DRR_1_part1.png      NON DRR           4.0
# 89   PATHOGEN      ICC1204.1_part1.png      NON DRR           5.0
# 90   PATHOGEN      ICC1205.1_part1.png      NON DRR           4.0
# 91   PATHOGEN  ICC1214_DRR_1_part1.png      NON DRR           5.0
# 92   PATHOGEN      ICC1228.1_part1.png      NON DRR           5.0
# 93   PATHOGEN      ICC1229.1_part1.png      NON DRR           4.0
# 94   PATHOGEN      ICC1232.1_part1.png      NON DRR           5.0
# 95   PATHOGEN  ICC1234_DRR_1_part1.png      NON DRR           4.0
# 96   PATHOGEN   ICC12369_DRR_part1.png      NON DRR           5.0
# 97   PATHOGEN      ICC1237.1_part1.png      NON DRR           4.0
# 98   PATHOGEN   ICC12377_DRR_part1.png      NON DRR           4.0
# 99   PATHOGEN      ICC1240.1_part1.png      NON DRR           5.0
# 100  PATHOGEN   ICC12438_DRR_part1.png      NON DRR           4.0
# 101  PATHOGEN   ICC12441_DRR_part1.png      NON DRR           4.0
# 102  PATHOGEN   ICC12442_DRR_part1.png      NON DRR           4.0
# 103  PATHOGEN   ICC12443_DRR_part1.png      NON DRR           5.0
# 104  PATHOGEN   ICC12445_DRR_part1.png      NON DRR           4.0
# 105  PATHOGEN      ICC1246.1_part1.png      NON DRR           3.0
# 106  PATHOGEN   ICC12466_DRR_part1.png      NON DRR           4.0
# 107  PATHOGEN      ICC1250.1_part1.png      NON DRR           5.0
# 108  PATHOGEN      ICC1265.1_part1.png      NON DRR           4.0
# 109  PATHOGEN  ICC1271_DRR_1_part1.png      NON DRR           5.0
# 110  PATHOGEN      ICC1272.1_part1.png      NON DRR           4.0
# 111  PATHOGEN      ICC1285.1_part1.png      NON DRR           4.0
# 112  PATHOGEN         ICC128_part1.png      NON DRR           5.0
# 113  PATHOGEN      ICC1291.1_part1.png      NON DRR           4.0
# 114  PATHOGEN      ICC1295.1_part1.png      NON DRR           5.0
# 115  PATHOGEN      ICC1296.1_part1.png      NON DRR           4.0
# 116  PATHOGEN      ICC1297.1_part1.png      NON DRR           4.0
# 117  PATHOGEN  ICC1298_DRR_1_part1.png      NON DRR           4.0
# 118  PATHOGEN    ICC12_DRR_1_part1.png      NON DRR           4.0
# 119  PATHOGEN      ICC1315.1_part1.png      NON DRR           5.0
# 120  PATHOGEN      ICC1337.1_part1.png      NON DRR           4.0
# 121  PATHOGEN      ICC1338.1_part1.png      NON DRR           5.0
# 122  PATHOGEN      ICC1356.1_part1.png      NON DRR           4.0
# 123  PATHOGEN      ICC1360.1_part1.png      NON DRR           5.0
# 124  PATHOGEN         ICC136_part1.png      NON DRR           4.0
# 125  PATHOGEN      ICC1392.1_part1.png      NON DRR           4.0
# 126  PATHOGEN   ICC13939_DRR_part1.png      NON DRR           4.0
# 127  PATHOGEN      ICC1397.1_part1.png      NON DRR           5.0
# 128  PATHOGEN      ICC1398.1_part1.png      NON DRR           4.0
# 129  PATHOGEN      ICC1402.1_part1.png      NON DRR           4.0
# 130  PATHOGEN      ICC1419.1_part1.png      NON DRR           4.0
# 131  PATHOGEN      ICC1422.1_part1.png      NON DRR           4.0
# 132  PATHOGEN      ICC1424.1_part1.png      NON DRR           3.0
# 133  PATHOGEN      ICC1431.1_part1.png      NON DRR           5.0
# 134  PATHOGEN   ICC14401_DRR_part1.png      NON DRR           5.0
# 135  PATHOGEN   ICC14410_DRR_part1.png      NON DRR           4.0
# 136  PATHOGEN      ICC1443.1_part1.png      NON DRR           4.0
# 137  PATHOGEN   ICC14431_DRR_part1.png      NON DRR           5.0
# 138  PATHOGEN      ICC1445.1_part1.png      NON DRR           4.0
# 139  PATHOGEN      ICC1449.1_part1.png      NON DRR           4.0
# 140  PATHOGEN      ICC1498.1_part1.png      NON DRR           4.0
# 141  PATHOGEN      ICC1499.1_part1.png      NON DRR           4.0
# 142  PATHOGEN      ICC1505.1_part1.png      NON DRR           5.0
# 143  PATHOGEN      ICC1507.1_part1.png      NON DRR           5.0
# 144  PATHOGEN      ICC1510.1_part1.png      NON DRR           5.0
# 145  PATHOGEN      ICC1520.1_part1.png      NON DRR           3.0
# 146  PATHOGEN         ICC153_part1.png      NON DRR           3.0
# 147  PATHOGEN      ICC1553.1_part1.png      NON DRR           4.0
# 148  PATHOGEN      ICC1560.1_part1.png      NON DRR           4.0
# 149  PATHOGEN      ICC1569.1_part1.png      NON DRR           4.0
# 150  PATHOGEN      ICC1579.1_part1.png      NON DRR           4.0
# 151  PATHOGEN      ICC1594.1_part1.png      NON DRR           4.0
# 152  PATHOGEN      ICC1599.1_part1.png      NON DRR           4.0
# 153  PATHOGEN          ICC15_part1.png      NON DRR           4.0
# 154  PATHOGEN      ICC1600.1_part1.png      NON DRR           5.0
# 155  PATHOGEN      ICC1609.1_part1.png      NON DRR           4.0
# 156  PATHOGEN      ICC1611.1_part1.png      NON DRR           5.0
# 157  PATHOGEN      ICC1616.1_part1.png      NON DRR           4.0
# 158  PATHOGEN         ICC161_part1.png      NON DRR           5.0
# 159  PATHOGEN      ICC1629.1_part1.png      NON DRR           5.0
# 160  PATHOGEN         ICC166_part1.png      NON DRR           4.0
# 161  PATHOGEN         ICC168_part1.png      NON DRR           4.0
# 162  PATHOGEN         ICC169_part1.png      NON DRR           4.0
# 163  PATHOGEN   ICC170_DRR_1_part1.png      NON DRR           4.0
# 164  PATHOGEN         ICC176_part1.png      NON DRR           4.0
# 165  PATHOGEN   ICC181_DRR_1_part1.png      NON DRR           5.0
# 166  PATHOGEN   ICC182-DRR_1_part1.png      NON DRR           3.0
# 167  PATHOGEN   ICC182_DRR_2_part1.png      NON DRR           4.0
# 168  PATHOGEN         ICC184_part1.png      NON DRR           3.0
# 169  PATHOGEN    ICC18_DRR_1_part1.png      NON DRR           4.0
# 170  PATHOGEN  ICC1901_DRR_1_part1.png      NON DRR           4.0
# 171  PATHOGEN  ICC1902_DRR_1_part1.png      NON DRR           5.0
# 172  PATHOGEN         ICC190_part1.png      NON DRR           5.0
# 173  PATHOGEN  ICC1925_DRR_1_part1.png      NON DRR           4.0
# 174  PATHOGEN  ICC2039_DRR_1_part1.png      NON DRR           4.0
# 175  PATHOGEN   ICC209_DRR_1_part1.png      NON DRR           5.0
# 176  PATHOGEN  ICC2165_DRR_1_part1.png      NON DRR           4.0
# 177  PATHOGEN   ICC216_DRR_1_part1.png      NON DRR           4.0
# 178  PATHOGEN         ICC219_part1.png      NON DRR           4.0
# 179  PATHOGEN  ICC2237_DRR_1_part1.png      NON DRR           4.0
# 180  PATHOGEN         ICC228_part1.png      NON DRR           4.0
# 181  PATHOGEN         ICC229_part1.png      NON DRR           5.0
# 182  PATHOGEN         ICC237_part1.png      NON DRR           4.0
# 183  PATHOGEN   ICC240_DRR_1_part1.png      NON DRR           5.0
# 184  PATHOGEN  ICC2430_DRR_1_part1.png      NON DRR           4.0
# 185  PATHOGEN  ICC2461_DRR_1_part1.png      NON DRR           4.0
# 186  PATHOGEN   ICC250_DRR_1_part1.png      NON DRR           4.0
# 187  PATHOGEN   ICC253_DRR_1_part1.png      NON DRR           4.0
# 188  PATHOGEN         ICC255_part1.png      NON DRR           4.0
# 189  PATHOGEN         ICC257_part1.png      NON DRR           5.0
# 190  PATHOGEN  ICC2616_DRR_1_part1.png      NON DRR           4.0
# 191  PATHOGEN   ICC265_DRR_1_part1.png      NON DRR           3.0
# 192  PATHOGEN          ICC26_part1.png      NON DRR           5.0
# 193  PATHOGEN  ICC2858_DRR_1_part1.png      NON DRR           4.0
# 194  PATHOGEN  ICC2883_DRR_1_part1.png      NON DRR           4.0
# 195  PATHOGEN         ICC299_part1.png      NON DRR           4.0
# 196  PATHOGEN           ICC2_part1.png      NON DRR           4.0
# 197  PATHOGEN         ICC311_part1.png      NON DRR           4.0
# 198  PATHOGEN         ICC315_part1.png      NON DRR           3.0
# 199  PATHOGEN         ICC317_part1.png      NON DRR           3.0
# 200  PATHOGEN         ICC324_part1.png      NON DRR           5.0
# 201  PATHOGEN         ICC337_part1.png      NON DRR           4.0
# 202  PATHOGEN         ICC338_part1.png      NON DRR           4.0
# 203  PATHOGEN  ICC3392_DRR_1_part1.png      NON DRR           4.0
# 204  PATHOGEN         ICC342_part1.png      NON DRR           4.0
# 205  PATHOGEN         ICC343_part1.png      NON DRR           4.0
# 206  PATHOGEN  ICC3448_DRR_1_part1.png      NON DRR           4.0
# 207  PATHOGEN         ICC344_part1.png      NON DRR           4.0
# 208  PATHOGEN         ICC350_part1.png      NON DRR           4.0
# 209  PATHOGEN         ICC353_part1.png      NON DRR           4.0
# 210  PATHOGEN  ICC3562_DRR_1_part1.png      NON DRR           4.0
# 211  PATHOGEN  ICC3573_DRR_1_part1.png      NON DRR           4.0
# 212  PATHOGEN  ICC3597_DRR_1_part1.png      NON DRR           4.0
# 213  PATHOGEN  ICC3599_DRR_1_part1.png      NON DRR           4.0
# 214  PATHOGEN  ICC3606_DRR_1_part1.png      NON DRR           3.0
# 215  PATHOGEN  ICC3650_DRR_1_part1.png      NON DRR           4.0
# 216  PATHOGEN  ICC3737_DRR_1_part1.png      NON DRR           3.0
# 217  PATHOGEN  ICC3742_DRR_1_part1.png      NON DRR           5.0
# 218  PATHOGEN         ICC383_part1.png      NON DRR           3.0
# 219  PATHOGEN  ICC3854_DRR_1_part1.png      NON DRR           4.0
# 220  PATHOGEN  ICC3855_DRR_1_part1.png      NON DRR           4.0
# 221  PATHOGEN         ICC398_part1.png      NON DRR           4.0
# 222  PATHOGEN         ICC403_part1.png      NON DRR           3.0
# 223  PATHOGEN  ICC4066_DRR_1_part1.png      NON DRR           4.0
# 224  PATHOGEN   ICC413_DRR_1_part1.png      NON DRR           4.0
# 225  PATHOGEN  ICC4200_DRR_1_part1.png      NON DRR           4.0
# 226  PATHOGEN          ICC42_part1.png      NON DRR           3.0
# 227  PATHOGEN         ICC437_part1.png      NON DRR           4.0
# 228  PATHOGEN    ICC43_DRR_1_part1.png      NON DRR           4.0
# 229  PATHOGEN         ICC440_part1.png      NON DRR           4.0
# 230  PATHOGEN         ICC442_part1.png      NON DRR           3.0
# 231  PATHOGEN  ICC4485_DRR_1_part1.png      NON DRR           4.0
# 232  PATHOGEN         ICC448_part1.png      NON DRR           4.0
# 233  PATHOGEN  ICC4490_DRR_1_part1.png      NON DRR           4.0
# 234  PATHOGEN  ICC4509_DRR_1_part1.png      NON DRR           4.0
# 235  PATHOGEN  ICC4529_DRR_1_part1.png      NON DRR           4.0
# 236  PATHOGEN   ICC454_DRR_1_part1.png      NON DRR           4.0
# 237  PATHOGEN         ICC455_part1.png      NON DRR           4.0
# 238  PATHOGEN          ICC45_part1.png      NON DRR           4.0
# 239  PATHOGEN  ICC4640_DRR_1_part1.png      NON DRR           4.0
# 240  PATHOGEN  ICC4785_DRR_1_part1.png      NON DRR           4.0
# 241  PATHOGEN  ICC4787_DRR_1_part1.png      NON DRR           4.0
# 242  PATHOGEN  ICC4827_DRR_1_part1.png      NON DRR           4.0
# 243  PATHOGEN  ICC4847_DRR_1_part1.png      NON DRR           4.0
# 244  PATHOGEN  ICC4850_DRR_1_part1.png      NON DRR           5.0
# 245  PATHOGEN  ICC4919_DRR_1_part1.png      NON DRR           4.0
# 246  PATHOGEN  ICC4940_DRR_1_part1.png      NON DRR           4.0
# 247  PATHOGEN     ICC4958_D1_part1.png      NON DRR           5.0
# 248  PATHOGEN  ICC4974_DRR_1_part1.png      NON DRR           5.0
# 249  PATHOGEN  ICC4987_DRR_1_part1.png      NON DRR           4.0
# 250  PATHOGEN  ICC5004_DRR_1_part1.png      NON DRR           3.0
# 251  PATHOGEN  ICC5006_DRR_1_part1.png      NON DRR           4.0
# 252  PATHOGEN  ICC5024_DRR_1_part1.png      NON DRR           4.0
# 253  PATHOGEN  ICC5103_DRR_1_part1.png      NON DRR           4.0
# 254  PATHOGEN  ICC5105_DRR_1_part1.png      NON DRR           5.0
# 255  PATHOGEN  ICC5618_DRR_1_part1.png      NON DRR           4.0
# 256  PATHOGEN  ICC5726_DRR_1_part1.png      NON DRR           4.0
# 257  PATHOGEN        ICC5762_part1.png      NON DRR           5.0
# 258  PATHOGEN        ICC5778_part1.png      NON DRR           4.0
# 259  PATHOGEN        ICC5780_part1.png      NON DRR           4.0
# 260  PATHOGEN        ICC5811_part1.png      NON DRR           4.0
# 261  PATHOGEN        ICC5915_part1.png      NON DRR           4.0
# 262  PATHOGEN        ICC5923_part1.png      NON DRR           4.0
# 263  PATHOGEN   ICC595-DRR_1_part1.png      NON DRR           4.0
# 264  PATHOGEN   ICC599_DRR_1_part1.png      NON DRR           4.0
# 265  PATHOGEN   ICC607_DRR_1_part1.png      NON DRR           4.0
# 266  PATHOGEN        ICC6295_part1.png      NON DRR           4.0
# 267  PATHOGEN        ICC6347_part1.png      NON DRR           4.0
# 268  PATHOGEN      ICC6359.1_part1.png      NON DRR           4.0
# 269  PATHOGEN        ICC6384_part1.png      NON DRR           4.0
# 270  PATHOGEN      ICC6401.1_part1.png      NON DRR           4.0
# 271  PATHOGEN      ICC6410.1_part1.png      NON DRR           5.0
# 272  PATHOGEN        ICC6419_part1.png      NON DRR           4.0
# 273  PATHOGEN      ICC6423.1_part1.png      NON DRR           5.0
# 274  PATHOGEN      ICC6438.1_part1.png      NON DRR           5.0
# 275  PATHOGEN      ICC6441.1_part1.png      NON DRR           4.0
# 276  PATHOGEN        ICC6445_part1.png      NON DRR           4.0
# 277  PATHOGEN      ICC6448.1_part1.png      NON DRR           4.0
# 278  PATHOGEN      ICC6452.1_part1.png      NON DRR           4.0
# 279  PATHOGEN    ICC6480_DRR_part1.png      NON DRR           4.0
# 280  PATHOGEN    ICC6480_DRR_part2.png      NON DRR           5.0
# 281  PATHOGEN      ICC6483.1_part1.png      NON DRR           4.0
# 282  PATHOGEN      ICC6492.1_part1.png      NON DRR           4.0
# 283  PATHOGEN        ICC6497_part1.png      NON DRR           5.0
# 284  PATHOGEN      ICC6498.1_part1.png      NON DRR           4.0
# 285  PATHOGEN    ICC64_DRR_1_part1.png      NON DRR           4.0
# 286  PATHOGEN        ICC6504_part1.png      NON DRR           4.0
# 287  PATHOGEN      ICC6510.1_part1.png      NON DRR           4.0
# 288  PATHOGEN        ICC6537_part1.png      NON DRR           5.0
# 289  PATHOGEN      ICC6551.1_part1.png      NON DRR           4.0
# 290  PATHOGEN        ICC6566_part1.png      NON DRR           4.0
# 291  PATHOGEN        ICC6571_part1.png      NON DRR           4.0
# 292  PATHOGEN        ICC6579_part1.png      NON DRR           5.0
# 293  PATHOGEN        ICC6616_part1.png      NON DRR           4.0
# 294  PATHOGEN        ICC6659_part1.png      NON DRR           4.0
# 295  PATHOGEN       ICC666.3_part1.png      NON DRR           5.0
# 296  PATHOGEN      ICC6661.1_part1.png      NON DRR           4.0
# 297  PATHOGEN        ICC6671_part1.png      NON DRR           4.0
# 298  PATHOGEN      ICC6723.1_part1.png      NON DRR           4.0
# 299  PATHOGEN        ICC6731_part1.png      NON DRR           4.0
# 300  PATHOGEN        ICC6732_part1.png      NON DRR           5.0
# 301  PATHOGEN    ICC6743_DRR_part1.png      NON DRR           4.0
# 302  PATHOGEN    ICC6743_DRR_part2.png      NON DRR           5.0
# 303  PATHOGEN    ICC6756_DRR_part1.png      NON DRR           5.0
# 304  PATHOGEN    ICC6756_DRR_part2.png      NON DRR           5.0
# 305  PATHOGEN      ICC6777.1_part1.png      NON DRR           5.0
# 306  PATHOGEN    ICC6796_DRR_part1.png      NON DRR           3.0
# 307  PATHOGEN    ICC6796_DRR_part2.png      NON DRR           5.0
# 308  PATHOGEN          ICC67_part1.png      NON DRR           4.0
# 309  PATHOGEN    ICC6801_DRR_part1.png      NON DRR           4.0
# 310  PATHOGEN    ICC6801_DRR_part2.png      NON DRR           5.0
# 311  PATHOGEN    ICC6803_DRR_part1.png      NON DRR           4.0
# 312  PATHOGEN    ICC6803_DRR_part2.png      NON DRR           4.0
# 313  PATHOGEN        ICC6804_part1.png      NON DRR           5.0
# 314  PATHOGEN      ICC6811.1_part1.png      NON DRR           5.0
# 315  PATHOGEN    ICC6815_DRR_part1.png      NON DRR           4.0
# 316  PATHOGEN    ICC6815_DRR_part2.png      NON DRR           5.0
# 317  PATHOGEN    ICC6817_DRR_part1.png      NON DRR           4.0
# 318  PATHOGEN    ICC6817_DRR_part2.png      NON DRR           5.0
# 319  PATHOGEN    ICC6818_DRR_part1.png      NON DRR           4.0
# 320  PATHOGEN    ICC6818_DRR_part2.png      NON DRR           4.0
# 321  PATHOGEN    ICC6819_DRR_part1.png      NON DRR           5.0
# 322  PATHOGEN    ICC6819_DRR_part2.png      NON DRR           5.0
# 323  PATHOGEN    ICC6821_DRR_part1.png      NON DRR           5.0
# 324  PATHOGEN    ICC6821_DRR_part2.png      NON DRR           5.0
# 325  PATHOGEN    ICC6822_DRR_part1.png      NON DRR           4.0
# 326  PATHOGEN    ICC6822_DRR_part2.png      NON DRR           4.0
# 327  PATHOGEN    ICC6843_DRR_part1.png      NON DRR           4.0
# 328  PATHOGEN    ICC6843_DRR_part2.png      NON DRR           4.0
# 329  PATHOGEN    ICC6858_DRR_part1.png      NON DRR           5.0
# 330  PATHOGEN    ICC6858_DRR_part2.png      NON DRR           3.0
# 331  PATHOGEN    ICC6876_DRR_part1.png      NON DRR           4.0
# 332  PATHOGEN    ICC6876_DRR_part2.png      NON DRR           4.0
# 333  PATHOGEN        ICC6877_part1.png      NON DRR           5.0
# 334  PATHOGEN    ICC6879_DRR_part1.png      NON DRR           3.0
# 335  PATHOGEN    ICC6879_DRR_part2.png      NON DRR           5.0
# 336  PATHOGEN    ICC6880_DRR_part1.png      NON DRR           4.0
# 337  PATHOGEN    ICC6880_DRR_part2.png      NON DRR           5.0
# 338  PATHOGEN    ICC6881_DRR_part1.png      NON DRR           4.0
# 339  PATHOGEN    ICC6881_DRR_part2.png      NON DRR           4.0
# 340  PATHOGEN    ICC6883_DRR_part1.png      NON DRR           4.0
# 341  PATHOGEN    ICC6883_DRR_part2.png      NON DRR           4.0
# 342  PATHOGEN    ICC6885_DRR_part1.png      NON DRR           4.0
# 343  PATHOGEN    ICC6885_DRR_part2.png      NON DRR           5.0
# 344  PATHOGEN    ICC68_DRR_1_part1.png      NON DRR           4.0
# 345  PATHOGEN    ICC6903_DRR_part1.png      NON DRR           4.0
# 346  PATHOGEN    ICC6903_DRR_part2.png      NON DRR           4.0
# 347  PATHOGEN    ICC6906_DRR_part1.png      NON DRR           4.0
# 348  PATHOGEN    ICC6906_DRR_part2.png      NON DRR           5.0
# 349  PATHOGEN    ICC6914_DRR_part1.png      NON DRR           5.0
# 350  PATHOGEN    ICC6914_DRR_part2.png      NON DRR           5.0
# 351  PATHOGEN    ICC6916_DRR_part1.png      NON DRR           4.0
# 352  PATHOGEN    ICC6916_DRR_part2.png      NON DRR           5.0
# 353  PATHOGEN    ICC6917_DRR_part1.png      NON DRR           4.0
# 354  PATHOGEN    ICC6917_DRR_part2.png      NON DRR           5.0
# 355  PATHOGEN        ICC6919_part1.png      NON DRR           4.0
# 356  PATHOGEN      ICC6921.1_part1.png      NON DRR           3.0
# 357  PATHOGEN    ICC6923_DRR_part1.png      NON DRR           4.0
# 358  PATHOGEN    ICC6923_DRR_part2.png      NON DRR           4.0
# 359  PATHOGEN    ICC6924_DRR_part1.png      NON DRR           4.0
# 360  PATHOGEN    ICC6926_DRR_part1.png      NON DRR           4.0
# 361  PATHOGEN    ICC6933_DRR_part1.png      NON DRR           4.0
# 362  PATHOGEN    ICC6939_DRR_part1.png      NON DRR           3.0
# 363  PATHOGEN    ICC6944_DRR_part1.png      NON DRR           4.0
# 364  PATHOGEN    ICC6949_DRR_part1.png      NON DRR           4.0
# 365  PATHOGEN    ICC6953_DRR_part1.png      NON DRR           3.0
# 366  PATHOGEN    ICC6962_DRR_part1.png      NON DRR           4.0
# 367  PATHOGEN    ICC6974_DRR_part1.png      NON DRR           4.0
# 368  PATHOGEN    ICC6982_DRR_part1.png      NON DRR           3.0
# 369  PATHOGEN    ICC6983_DRR_part1.png      NON DRR           4.0
# 370  PATHOGEN    ICC6984_DRR_part1.png      NON DRR           4.0
# 371  PATHOGEN    ICC6999_DRR_part1.png      NON DRR           4.0
# 372  PATHOGEN    ICC7000_DRR_part1.png      NON DRR           4.0
# 373  PATHOGEN    ICC7005_DRR_part1.png      NON DRR           3.0
# 374  PATHOGEN    ICC7014_DRR_part1.png      NON DRR           4.0
# 375  PATHOGEN        ICC7144_part1.png      NON DRR           5.0
# 376  PATHOGEN        ICC7172_part1.png      NON DRR           4.0
# 377  PATHOGEN        ICC7200_part1.png      NON DRR           5.0
# 378  PATHOGEN      ICC7201.1_part1.png      NON DRR           4.0
# 379  PATHOGEN        ICC7207_part1.png      NON DRR           4.0
# 380  PATHOGEN    ICC7401_DRR_part1.png      NON DRR           4.0
# 381  PATHOGEN          ICC75_part1.png      NON DRR           3.0
# 382  PATHOGEN    ICC7856_DRR_part1.png      NON DRR           4.0
# 383  PATHOGEN    ICC7869_DRR_part1.png      NON DRR           5.0
# 384  PATHOGEN          ICC80_part1.png      NON DRR           4.0
# 385  PATHOGEN   ICC860-DRR_1_part1.png      NON DRR           4.0
# 386  PATHOGEN          ICC86_part1.png      NON DRR           4.0
# 387  PATHOGEN   ICC880_DRR_1_part1.png      NON DRR           4.0
# 388  PATHOGEN  ICC8818_DRR_1_part1.png      NON DRR           4.0
# 389  PATHOGEN  ICC8872_DRR_1_part1.png      NON DRR           4.0
# 390  PATHOGEN  ICC8933_DRR_1_part1.png      NON DRR           5.0
# 391  PATHOGEN  ICC8967_DRR_1_part1.png      NON DRR           3.0
# 392  PATHOGEN  ICC8977_DRR_1_part1.png      NON DRR           5.0
# 393  PATHOGEN  ICC8980_DRR_1_part1.png      NON DRR           5.0
# 394  PATHOGEN    ICC9112_DRR_part1.png      NON DRR           5.0
# 395  PATHOGEN    ICC9112_DRR_part2.png      NON DRR           4.0
# 396  PATHOGEN    ICC9117_DRR_part1.png      NON DRR           4.0
# 397  PATHOGEN    ICC9117_DRR_part2.png      NON DRR           4.0
# 398  PATHOGEN    ICC9120_DRR_part1.png      NON DRR           4.0
# 399  PATHOGEN    ICC9120_DRR_part2.png      NON DRR           4.0
# 400  PATHOGEN    ICC9127_DRR_part1.png      NON DRR           4.0
# 401  PATHOGEN    ICC9127_DRR_part2.png      NON DRR           5.0
# 402  PATHOGEN    ICC9143_DRR_part1.png      NON DRR           4.0
# 403  PATHOGEN    ICC9143_DRR_part2.png      NON DRR           4.0
# 404  PATHOGEN    ICC91_DRR_1_part1.png      NON DRR           4.0
# 405  PATHOGEN          ICC92_part1.png      NON DRR           4.0
# 406  PATHOGEN    ICC9496_DRR_part1.png      NON DRR           4.0
# 407  PATHOGEN    ICC9496_DRR_part2.png      NON DRR           4.0
# 408  PATHOGEN    ICC9519_DRR_part1.png      NON DRR           5.0
# 409  PATHOGEN    ICC9519_DRR_part2.png      NON DRR           5.0
# 410  PATHOGEN    ICC9522_DRR_part1.png      NON DRR           5.0
# 411  PATHOGEN    ICC9522_DRR_part2.png      NON DRR           4.0
# 412  PATHOGEN          ICC95_part1.png      NON DRR           3.0
# 413  PATHOGEN    ICC9668_DRR_part1.png      NON DRR           5.0
# 414  PATHOGEN    ICC9668_DRR_part2.png      NON DRR           5.0
# 415  PATHOGEN        JG62_D1_part1.png      NON DRR           5.0
# 416  PATHOGEN        L550_D1_part1.png      NON DRR           5.0
