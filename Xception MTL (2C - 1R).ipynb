# %%
import os
import re
import pandas as pd
import numpy as np
from tensorflow import keras
import tensorflow as tf
# Out:
# C:\Users\91999\anaconda3\envs\myenv2\lib\site-packages\tensorflow\python\keras\engine\training_arrays_v1.py:37: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 1.21.6)
#   from scipy.sparse import issparse  # pylint: disable=g-import-not-at-top

# %%
model_path = r'C:\Users\91999\OneDrive\Desktop\DRR project\general\trained_model\A1\DRR_MTL_3c_1R_250e'

# %%
base_path = r'D:\new camera'

# %%
output_path = r'C:\Users\91999\OneDrive\Desktop\trial A1.xlsx'

# %%
# Define image dimensions and load the model
img_dim = 224

model =  tf.keras.models.load_model(model_path)

# %%
# Extract image file paths
image_file_paths = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.endswith((".png", ".PNG", ".jpeg")):  # Add other image extensions if necessary
            image_file_paths.append(os.path.join(root, file))

# %%
# Load test dataset without shuffling to maintain order
test_ds = keras.utils.image_dataset_from_directory(
    base_path,
    image_size=(img_dim, img_dim),
    label_mode='int',
    batch_size=1000,
    shuffle=False  # Ensure no shuffling to keep image file order intact
)
# Out:
# Found 846 files belonging to 2 classes.

# %%
class_names = test_ds.class_names

# %%
resize_and_rescale = keras.Sequential([
  #layers.experimental.preprocessing.Resizing(IMG_SIZE, IMG_SIZE),
  keras.layers.experimental.preprocessing.Rescaling(1./255)
])

# %%
data_augmentation = keras.Sequential([
    keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    keras.layers.experimental.preprocessing.RandomRotation(0.1),
    #keras.layers.experimental.preprocessing.RandomFlip("vertical"),
])

# %%
# Function to prepare dataset
AUTOTUNE = tf.data.AUTOTUNE
def prepare(ds, augment=False):
    def resize_and_rescale(image, label):
        image = tf.image.resize(image, [img_dim, img_dim])
        image = tf.cast(image, tf.float32) / 255.0
        return image, label
    
    # Apply resizing and rescaling
    ds = ds.map(lambda x, y: (resize_and_rescale(x, y)), num_parallel_calls=AUTOTUNE)
    
    # Apply data augmentation if specified
    if augment:
        data_augmentation = tf.keras.Sequential([
            tf.keras.layers.RandomFlip("horizontal_and_vertical"),
            tf.keras.layers.RandomRotation(0.2)
        ])
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), num_parallel_calls=AUTOTUNE)
        
    # Use buffered prefetching
    return ds.prefetch(buffer_size=AUTOTUNE)

# %%
# Prepare the test dataset
test_ds = prepare(test_ds)

# %%
# Separate the images and labels
ts_image_batch,tr_label_batch = next(iter(test_ds))
ts_image_batch = np.asarray(ts_image_batch)

# %%
preds = model.predict(ts_image_batch)
# Out:
# 27/27 [==============================] - 118s 4s/step

# %%
# Extract predicted class indices and scores
y_pred_3c = []
for i in preds[0]:
    y_pred_3c = np.append(y_pred_3c,np.argmax(i))

y_pred_scores = []
for i in preds[1]:
    y_pred_scores = np.append(y_pred_scores,int(abs(np.round(i,0))))

# %%
actual_classes = [class_names[label] for label in tr_label_batch]
L = ['CONTROL','PATHOGEN/NON DRR','PATHOGEN/NON DRR']
y_pred_classes = [L[int(label)] for label in y_pred_3c]

# %%
# Extract image file names using regex
#image_file_names = [re.match(file_name_pattern, file_path).group(1) for file_path in image_file_paths[:len(ts_label_batch)]]
image_file_names = [os.path.basename(file_path) for file_path in image_file_paths[:len(ts_image_batch)]]

# %%
print(len(image_file_names), len(y_pred_classes), len(y_pred_scores))
# Out:
# 846 846 846

# %%
image_file_paths = []
for root, dirs, files in os.walk(base_path):
    for file in files:
        if file.endswith((".png", ".jpg", ".jpeg")):  # Add other image extensions if necessary
            image_file_paths.append(os.path.join(root, file))

print("Total images found:", len(image_file_paths))
# Out:
# Total images found: 846

# %%
# Create a DataFrame with Image Name, Predicted Class, Predicted Score, Actual Class
results_df = pd.DataFrame({
    'Folder': actual_classes,
    'Image Name': image_file_names,
    'Predicted Class': y_pred_classes,
    'Predicted Score': y_pred_scores
})

# %%
# Save the DataFrame to an Excel file with a different name

results_df.to_excel(excel_writer=output_path, index=False)

print(f"Results have been saved to {output_path}")


pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)
pd.set_option('display.colheader_justify', 'center')
pd.set_option('display.precision', 2)
display(results_df)
# Out:
# Results have been saved to C:\Users\91999\OneDrive\Desktop\trial A1.xlsx
#       Folder      Image Name    Predicted Class  Predicted Score
# 0     CONTROL      DSCF5264.png      NON DRR           6.0
# 1     CONTROL      DSCF5265.png      NON DRR           6.0
# 2     CONTROL      DSCF5266.png      NON DRR           6.0
# 3     CONTROL      DSCF5267.png      NON DRR           6.0
# 4     CONTROL      DSCF5268.png      NON DRR           6.0
# 5     CONTROL      DSCF5269.png      NON DRR           6.0
# 6     CONTROL      DSCF5270.png      NON DRR           6.0
# 7     CONTROL      DSCF5271.png      NON DRR           6.0
# 8     CONTROL      DSCF5272.png      NON DRR           5.0
# 9     CONTROL      DSCF5273.png      NON DRR           6.0
# 10    CONTROL      DSCF5274.png      NON DRR           6.0
# 11    CONTROL      DSCF5275.png      NON DRR           6.0
# 12    CONTROL      DSCF5276.png      NON DRR           6.0
# 13    CONTROL      DSCF5277.png      NON DRR           6.0
# 14    CONTROL      DSCF5278.png      NON DRR           6.0
# 15    CONTROL      DSCF5279.png      NON DRR           6.0
# 16    CONTROL      DSCF5280.png      NON DRR           6.0
# 17    CONTROL      DSCF5281.png      NON DRR           6.0
# 18    CONTROL      DSCF5282.png      NON DRR           6.0
# 19    CONTROL      DSCF5283.png      NON DRR           6.0
# 20    CONTROL      DSCF5284.png      NON DRR           6.0
# 21    CONTROL      DSCF5285.png      NON DRR           6.0
# 22    CONTROL      DSCF5286.png      NON DRR           6.0
# 23    CONTROL      DSCF5287.png      NON DRR           6.0
# 24    CONTROL      DSCF5288.png      NON DRR           6.0
# 25    CONTROL      DSCF5289.png      NON DRR           6.0
# 26    CONTROL      DSCF5290.png      NON DRR           6.0
# 27    CONTROL      DSCF5291.png      NON DRR           6.0
# 28    CONTROL      DSCF5292.png      NON DRR           6.0
# 29    CONTROL      DSCF5293.png      NON DRR           6.0
# 30    CONTROL      DSCF5294.png      NON DRR           6.0
# 31    CONTROL      DSCF5295.png      NON DRR           6.0
# 32    CONTROL      DSCF5296.png      NON DRR           6.0
# 33    CONTROL      DSCF5297.png      NON DRR           6.0
# 34    CONTROL      DSCF5298.png      NON DRR           6.0
# 35    CONTROL      DSCF5299.png      NON DRR           6.0
# 36    CONTROL      DSCF5300.png      NON DRR           6.0
# 37    CONTROL      DSCF5301.png      NON DRR           4.0
# 38    CONTROL      DSCF5303.png      NON DRR           6.0
# 39    CONTROL      DSCF5304.png      NON DRR           6.0
# 40    CONTROL      DSCF5305.png      NON DRR           6.0
# 41    CONTROL      DSCF5306.png      NON DRR           6.0
# 42    CONTROL      DSCF5307.png      NON DRR           6.0
# 43    CONTROL      DSCF5308.png      NON DRR           6.0
# 44    CONTROL      DSCF5309.png      NON DRR           6.0
# 45    CONTROL      DSCF5310.png      NON DRR           6.0
# 46    CONTROL      DSCF5311.png      NON DRR           6.0
# 47    CONTROL      DSCF5312.png      NON DRR           6.0
# 48    CONTROL      DSCF5313.png      NON DRR           6.0
# 49    CONTROL      DSCF5314.png      NON DRR           6.0
# 50    CONTROL      DSCF5315.png      NON DRR           6.0
# 51    CONTROL      DSCF5316.png      NON DRR           6.0
# 52    CONTROL      DSCF5317.png      NON DRR           6.0
# 53    CONTROL      DSCF5318.png      NON DRR           6.0
# 54    CONTROL      DSCF5319.png      NON DRR           6.0
# 55    CONTROL      DSCF5320.png      NON DRR           6.0
# 56    CONTROL      DSCF5321.png      NON DRR           6.0
# 57    CONTROL      DSCF5322.png      NON DRR           6.0
# 58    CONTROL      DSCF5323.png      NON DRR           6.0
# 59    CONTROL      DSCF5324.png      NON DRR           6.0
# 60    CONTROL      DSCF5325.png      CONTROL           2.0
# 61    CONTROL      DSCF5326.png      NON DRR           5.0
# 62    CONTROL      DSCF5327.png      NON DRR           6.0
# 63    CONTROL      DSCF5328.png      NON DRR           6.0
# 64    CONTROL      DSCF5329.png      NON DRR           6.0
# 65    CONTROL      DSCF5331.png      NON DRR           6.0
# 66    CONTROL      DSCF5332.png      NON DRR           6.0
# 67    CONTROL      DSCF5333.png      NON DRR           6.0
# 68    CONTROL      DSCF5334.png      NON DRR           6.0
# 69    CONTROL      DSCF5335.png      NON DRR           6.0
# 70    CONTROL      DSCF5336.png      NON DRR           6.0
# 71    CONTROL      DSCF5337.png      NON DRR           6.0
# 72    CONTROL      DSCF5338.png      NON DRR           6.0
# 73    CONTROL      DSCF5339.png     PATHOGEN           4.0
# 74    CONTROL      DSCF5340.png      NON DRR           6.0
# 75    CONTROL      DSCF5341.png      NON DRR           6.0
# 76    CONTROL      DSCF5342.png      NON DRR           6.0
# 77    CONTROL      DSCF5343.png      NON DRR           6.0
# 78    CONTROL      DSCF5344.png      CONTROL           0.0
# 79    CONTROL      DSCF5345.png      CONTROL           0.0
# 80    CONTROL      DSCF5346.png      CONTROL           0.0
# 81    CONTROL      DSCF5347.png      CONTROL           0.0
# 82    CONTROL      DSCF5348.png      CONTROL           0.0
# 83    CONTROL      DSCF5349.png      CONTROL           0.0
# 84    CONTROL      DSCF5350.png      CONTROL           0.0
# 85    CONTROL      DSCF5351.png      CONTROL           0.0
# 86    CONTROL      DSCF5352.png      CONTROL           0.0
# 87    CONTROL      DSCF5353.png      CONTROL           0.0
# 88    CONTROL      DSCF5354.png      CONTROL           0.0
# 89    CONTROL      DSCF5355.png      CONTROL           0.0
# 90    CONTROL      DSCF5356.png      CONTROL           0.0
# 91    CONTROL      DSCF5357.png      CONTROL           0.0
# 92    CONTROL      DSCF5358.png      CONTROL           0.0
# 93    CONTROL      DSCF5359.png      CONTROL           0.0
# 94    CONTROL      DSCF5360.png      CONTROL           0.0
# 95    CONTROL      DSCF5361.png      CONTROL           0.0
# 96    CONTROL      DSCF5362.png      CONTROL           0.0
# 97    CONTROL      DSCF5363.png      CONTROL           0.0
# 98    CONTROL      DSCF5364.png      NON DRR           6.0
# 99    CONTROL      DSCF5365.png      NON DRR           6.0
# 100   CONTROL      DSCF5366.png      NON DRR           6.0
# 101   CONTROL      DSCF5367.png      NON DRR           6.0
# 102   CONTROL      DSCF5368.png      NON DRR           6.0
# 103   CONTROL      DSCF5369.png      NON DRR           6.0
# 104   CONTROL      DSCF5370.png      NON DRR           6.0
# 105   CONTROL      DSCF5371.png      NON DRR           6.0
# 106   CONTROL      DSCF5372.png      NON DRR           6.0
# 107   CONTROL      DSCF5373.png      NON DRR           6.0
# 108   CONTROL      DSCF5374.png      NON DRR           6.0
# 109   CONTROL      DSCF5375.png      NON DRR           6.0
# 110   CONTROL      DSCF5376.png      NON DRR           6.0
# 111   CONTROL      DSCF5377.png      NON DRR           6.0
# 112   CONTROL      DSCF5378.png      NON DRR           6.0
# 113   CONTROL      DSCF5379.png      NON DRR           6.0
# 114   CONTROL      DSCF5380.png      NON DRR           6.0
# 115   CONTROL      DSCF5381.png      NON DRR           6.0
# 116   CONTROL      DSCF5382.png      NON DRR           6.0
# 117   CONTROL      DSCF5383.png      NON DRR           6.0
# 118   CONTROL      DSCF5384.png      NON DRR           6.0
# 119   CONTROL      DSCF5385.png      NON DRR           6.0
# 120   CONTROL      DSCF5386.png      NON DRR           6.0
# 121   CONTROL      DSCF5387.png      NON DRR           6.0
# 122   CONTROL      DSCF5388.png      NON DRR           6.0
# 123   CONTROL      DSCF5389.png      NON DRR           6.0
# 124   CONTROL      DSCF5390.png      NON DRR           6.0
# 125   CONTROL      DSCF5391.png      NON DRR           6.0
# 126   CONTROL      DSCF5392.png      NON DRR           6.0
# 127   CONTROL      DSCF5393.png      NON DRR           6.0
# 128   CONTROL      DSCF5394.png      NON DRR           6.0
# 129   CONTROL      DSCF5395.png      NON DRR           6.0
# 130   CONTROL      DSCF5821.png      NON DRR           6.0
# 131   CONTROL      DSCF5822.png      NON DRR           6.0
# 132   CONTROL      DSCF5829.png      NON DRR           6.0
# 133   CONTROL      DSCF5830.png      NON DRR           6.0
# 134   CONTROL      DSCF5831.png      NON DRR           6.0
# 135   CONTROL      DSCF5832.png      NON DRR           6.0
# 136   CONTROL      DSCF5833.png      NON DRR           6.0
# 137   CONTROL      DSCF5837.png      NON DRR           6.0
# 138   CONTROL      DSCF5838.png      NON DRR           6.0
# 139   CONTROL      DSCF5839.png      NON DRR           6.0
# 140   CONTROL      DSCF5840.png      NON DRR           6.0
# 141   CONTROL      DSCF5841.png      NON DRR           6.0
# 142   CONTROL      DSCF5842.png      NON DRR           6.0
# 143   CONTROL      DSCF5843.png      NON DRR           6.0
# 144   CONTROL      DSCF5844.png      NON DRR           6.0
# 145   CONTROL      DSCF5845.png      NON DRR           6.0
# 146   CONTROL      DSCF5846.png      NON DRR           6.0
# 147   CONTROL      DSCF5847.png      NON DRR           6.0
# 148   CONTROL      DSCF5848.png      NON DRR           6.0
# 149   CONTROL      DSCF5849.png      NON DRR           6.0
# 150   CONTROL      DSCF5850.png      NON DRR           6.0
# 151   CONTROL      DSCF5851.png      NON DRR           6.0
# 152   CONTROL      DSCF5852.png      NON DRR           6.0
# 153   CONTROL      DSCF5853.png      NON DRR           6.0
# 154   CONTROL      DSCF5854.png      NON DRR           6.0
# 155   CONTROL      DSCF5855.png      NON DRR           6.0
# 156   CONTROL      DSCF5856.png      NON DRR           6.0
# 157   CONTROL      DSCF5857.png      NON DRR           6.0
# 158   CONTROL      DSCF5858.png      NON DRR           6.0
# 159   CONTROL      DSCF5859.png      NON DRR           6.0
# 160   CONTROL      DSCF5860.png      NON DRR           6.0
# 161   CONTROL      DSCF5861.png      NON DRR           6.0
# 162   CONTROL      DSCF5862.png      NON DRR           6.0
# 163   CONTROL      DSCF5863.png      NON DRR           6.0
# 164   CONTROL      DSCF5864.png      NON DRR           6.0
# 165   CONTROL      DSCF5865.png      NON DRR           6.0
# 166   CONTROL      DSCF5866.png      NON DRR           6.0
# 167   CONTROL      DSCF5867.png      NON DRR           6.0
# 168   CONTROL      DSCF5868.png      NON DRR           6.0
# 169   CONTROL      DSCF5870.png      NON DRR           6.0
# 170   CONTROL      DSCF5871.png      NON DRR           6.0
# 171   CONTROL      DSCF5872.png      NON DRR           6.0
# 172   CONTROL      DSCF5977.png      NON DRR           6.0
# 173   CONTROL      DSCF5978.png      NON DRR           6.0
# 174   CONTROL      DSCF5979.png      NON DRR           6.0
# 175   CONTROL      DSCF5980.png      NON DRR           6.0
# 176   CONTROL      DSCF5981.png      NON DRR           6.0
# 177   CONTROL      DSCF5982.png      NON DRR           6.0
# 178   CONTROL      DSCF5983.png      NON DRR           6.0
# 179   CONTROL      DSCF5984.png      NON DRR           6.0
# 180   CONTROL      DSCF5985.png      NON DRR           6.0
# 181   CONTROL      DSCF5986.png      NON DRR           6.0
# 182   CONTROL      DSCF5989.png      NON DRR           6.0
# 183   CONTROL      DSCF5990.png      NON DRR           6.0
# 184   CONTROL      DSCF5991.png      NON DRR           6.0
# 185   CONTROL      DSCF5992.png      NON DRR           6.0
# 186   CONTROL      DSCF5993.png      NON DRR           6.0
# 187   CONTROL      DSCF5994.png      NON DRR           6.0
# 188   CONTROL      DSCF5995.png      NON DRR           6.0
# 189   CONTROL      DSCF5996.png      NON DRR           6.0
# 190   CONTROL      DSCF5997.png      NON DRR           6.0
# 191   CONTROL      DSCF6001.png      NON DRR           6.0
# 192   CONTROL      DSCF6002.png      NON DRR           6.0
# 193   CONTROL      DSCF6003.png      NON DRR           6.0
# 194   CONTROL      DSCF6004.png      NON DRR           6.0
# 195   CONTROL      DSCF6005.png      NON DRR           6.0
# 196   CONTROL      DSCF6006.png      NON DRR           6.0
# 197   CONTROL      DSCF6007.png      NON DRR           6.0
# 198   CONTROL      DSCF6008.png      NON DRR           6.0
# 199   CONTROL      DSCF6009.png      NON DRR           6.0
# 200   CONTROL      DSCF6010.png      NON DRR           6.0
# 201   CONTROL      DSCF6011.png      NON DRR           6.0
# 202   CONTROL      DSCF6012.png      NON DRR           6.0
# 203   CONTROL      DSCF6013.png      NON DRR           6.0
# 204   CONTROL      DSCF6014.png      NON DRR           6.0
# 205   CONTROL      DSCF6015.png      NON DRR           6.0
# 206   CONTROL      DSCF6016.png      NON DRR           6.0
# 207   CONTROL      DSCF6017.png      NON DRR           6.0
# 208   CONTROL      DSCF6018.png      NON DRR           6.0
# 209   CONTROL      DSCF6019.png      NON DRR           6.0
# 210   CONTROL      DSCF6020.png      NON DRR           6.0
# 211   CONTROL      DSCF6021.png      NON DRR           6.0
# 212   CONTROL      DSCF6022.png      NON DRR           6.0
# 213   CONTROL      DSCF6023.png      NON DRR           6.0
# 214   CONTROL      DSCF6024.png      NON DRR           6.0
# 215   CONTROL      DSCF6025.png      NON DRR           6.0
# 216   CONTROL      DSCF6026.png      NON DRR           6.0
# 217   CONTROL      DSCF6027.png      NON DRR           6.0
# 218   CONTROL      DSCF6028.png      NON DRR           6.0
# 219   CONTROL      DSCF6029.png      NON DRR           6.0
# 220   CONTROL      DSCF6030.png      NON DRR           6.0
# 221   CONTROL      DSCF6031.png      NON DRR           6.0
# 222   CONTROL      DSCF6032.png      NON DRR           6.0
# 223   CONTROL      DSCF6033.png      NON DRR           6.0
# 224   CONTROL      DSCF6034.png      NON DRR           6.0
# 225   CONTROL      DSCF6035.png      NON DRR           6.0
# 226   CONTROL      DSCF6036.png      NON DRR           6.0
# 227   CONTROL      DSCF6037.png      NON DRR           6.0
# 228   CONTROL      DSCF6038.png      NON DRR           6.0
# 229   CONTROL      DSCF6039.png      NON DRR           6.0
# 230   CONTROL      DSCF6040.png      NON DRR           6.0
# 231   CONTROL      DSCF6041.png      NON DRR           6.0
# 232   CONTROL      DSCF6042.png      NON DRR           6.0
# 233   CONTROL      DSCF6043.png      NON DRR           6.0
# 234   CONTROL      DSCF6044.png      NON DRR           6.0
# 235   CONTROL      DSCF6045.png      NON DRR           6.0
# 236   CONTROL      DSCF6046.png      NON DRR           6.0
# 237   CONTROL      DSCF6047.png      NON DRR           6.0
# 238   CONTROL      DSCF6048.png      NON DRR           6.0
# 239   CONTROL      DSCF6049.png      NON DRR           6.0
# 240   CONTROL      DSCF6050.png      NON DRR           6.0
# 241   CONTROL      DSCF6051.png      NON DRR           6.0
# 242   CONTROL      DSCF6052.png      NON DRR           6.0
# 243   CONTROL      DSCF6053.png      NON DRR           6.0
# 244   CONTROL      DSCF6054.png      NON DRR           6.0
# 245   CONTROL      DSCF6055.png      NON DRR           6.0
# 246   CONTROL      DSCF6056.png      NON DRR           6.0
# 247   CONTROL      DSCF6057.png      NON DRR           6.0
# 248   CONTROL      DSCF6058.png      NON DRR           6.0
# 249   CONTROL      DSCF6059.png      NON DRR           6.0
# 250   CONTROL      DSCF6060.png      NON DRR           6.0
# 251   CONTROL      DSCF6062.png      NON DRR           6.0
# 252   CONTROL      DSCF6063.png      NON DRR           6.0
# 253   CONTROL      DSCF6064.png      NON DRR           6.0
# 254   CONTROL      DSCF6065.png      NON DRR           6.0
# 255   CONTROL      DSCF6066.png      NON DRR           6.0
# 256   CONTROL      DSCF6067.png      NON DRR           6.0
# 257   CONTROL      DSCF6070.png      NON DRR           6.0
# 258   CONTROL      DSCF6071.png      NON DRR           6.0
# 259   CONTROL      DSCF6072.png      NON DRR           6.0
# 260   CONTROL      DSCF6073.png      NON DRR           6.0
# 261   CONTROL      DSCF6074.png      NON DRR           6.0
# 262   CONTROL      DSCF6075.png      NON DRR           6.0
# 263   CONTROL      DSCF6076.png      NON DRR           6.0
# 264   CONTROL      DSCF6077.png      NON DRR           6.0
# 265   CONTROL      DSCF6078.png      NON DRR           6.0
# 266   CONTROL      DSCF6079.png      NON DRR           6.0
# 267   CONTROL      DSCF6080.png      NON DRR           6.0
# 268   CONTROL      DSCF6081.png      NON DRR           6.0
# 269   CONTROL      DSCF6082.png      NON DRR           6.0
# 270   CONTROL      DSCF6083.png      NON DRR           6.0
# 271   CONTROL      DSCF6084.png      NON DRR           6.0
# 272   CONTROL      DSCF6085.png      NON DRR           6.0
# 273   CONTROL      DSCF6089.png      NON DRR           6.0
# 274   CONTROL      DSCF6090.png      NON DRR           6.0
# 275   CONTROL      DSCF6091.png      NON DRR           6.0
# 276   CONTROL      DSCF6092.png      NON DRR           6.0
# 277   CONTROL      DSCF6093.png      NON DRR           6.0
# 278   CONTROL      DSCF6094.png      NON DRR           6.0
# 279   CONTROL      DSCF6095.png      NON DRR           6.0
# 280   CONTROL      DSCF6096.png      NON DRR           6.0
# 281   CONTROL      DSCF6097.png      NON DRR           6.0
# 282   CONTROL      DSCF6098.png      NON DRR           6.0
# 283   CONTROL      DSCF6099.png      NON DRR           6.0
# 284   CONTROL      DSCF6100.png      NON DRR           6.0
# 285   CONTROL      DSCF6101.png      NON DRR           6.0
# 286   CONTROL      IMG_8348.png      CONTROL           0.0
# 287   CONTROL      IMG_8349.png      CONTROL           0.0
# 288   CONTROL      IMG_8350.png      CONTROL           0.0
# 289   CONTROL      IMG_8679.png      CONTROL           0.0
# 290   CONTROL      IMG_8680.png      CONTROL           0.0
# 291   CONTROL      IMG_8681.png      CONTROL           0.0
# 292   CONTROL      IMG_8682.png      CONTROL           0.0
# 293   CONTROL      IMG_8683.png      CONTROL           0.0
# 294   CONTROL      IMG_8684.png      CONTROL           0.0
# 295   CONTROL      IMG_8686.png      CONTROL           0.0
# 296   CONTROL      IMG_8687.png      CONTROL           0.0
# 297   CONTROL      IMG_8688.png      CONTROL           0.0
# 298   CONTROL      IMG_8689.png      CONTROL           0.0
# 299   CONTROL      IMG_8690.png      CONTROL           0.0
# 300   CONTROL      IMG_8691.png      CONTROL           0.0
# 301   CONTROL      IMG_8692.png      CONTROL           0.0
# 302   CONTROL      IMG_8693.png      CONTROL           0.0
# 303   CONTROL      IMG_8694.png      CONTROL           0.0
# 304   CONTROL      IMG_8695.png      CONTROL           0.0
# 305   CONTROL      IMG_8696.png      CONTROL           0.0
# 306   CONTROL      IMG_8697.png      CONTROL           0.0
# 307   CONTROL      IMG_8698.png      CONTROL           0.0
# 308   CONTROL      IMG_8699.png      CONTROL           0.0
# 309   CONTROL      IMG_8700.png      CONTROL           0.0
# 310   CONTROL      IMG_8701.png      CONTROL           0.0
# 311   CONTROL      IMG_8702.png      CONTROL           0.0
# 312   CONTROL      IMG_8703.png      CONTROL           0.0
# 313   CONTROL      IMG_8704.png      CONTROL           0.0
# 314   CONTROL      IMG_8705.png      CONTROL           0.0
# 315   CONTROL      IMG_8706.png      CONTROL           0.0
# 316   CONTROL      IMG_8707.png      CONTROL           0.0
# 317   CONTROL      IMG_8708.png      CONTROL           0.0
# 318   CONTROL      IMG_8709.png      CONTROL           0.0
# 319   CONTROL      IMG_8710.png      CONTROL           0.0
# 320   CONTROL      IMG_8711.png      CONTROL           0.0
# 321   CONTROL      IMG_8712.png      CONTROL           0.0
# 322   CONTROL      IMG_8713.png      CONTROL           0.0
# 323   CONTROL      IMG_8714.png      CONTROL           0.0
# 324   CONTROL      IMG_8715.png      CONTROL           0.0
# 325   CONTROL      IMG_8716.png      CONTROL           0.0
# 326   CONTROL      IMG_8717.png      CONTROL           0.0
# 327   CONTROL      IMG_8718.png      CONTROL           0.0
# 328   CONTROL      IMG_8719.png      CONTROL           0.0
# 329   CONTROL      IMG_8720.png      CONTROL           0.0
# 330   CONTROL      IMG_8721.png      CONTROL           0.0
# 331   CONTROL      IMG_8722.png      CONTROL           0.0
# 332   CONTROL      IMG_8723.png      CONTROL           0.0
# 333   CONTROL      IMG_8725.png      CONTROL           0.0
# 334   CONTROL      IMG_8726.png      CONTROL           0.0
# 335   CONTROL      IMG_8727.png      CONTROL           0.0
# 336   CONTROL      IMG_8728.png      CONTROL           0.0
# 337   CONTROL      IMG_8729.png      CONTROL           0.0
# 338   CONTROL      IMG_8730.png      CONTROL           0.0
# 339   CONTROL      IMG_8731.png      CONTROL           0.0
# 340   CONTROL      IMG_8732.png      CONTROL           0.0
# 341   CONTROL      IMG_8733.png      CONTROL           0.0
# 342   CONTROL      IMG_8734.png      CONTROL           0.0
# 343   CONTROL      IMG_8735.png      CONTROL           0.0
# 344   CONTROL      IMG_8736.png      CONTROL           0.0
# 345   CONTROL      IMG_8737.png      CONTROL           1.0
# 346   CONTROL      IMG_8738.png      CONTROL           1.0
# 347   CONTROL      IMG_8739.png      CONTROL           0.0
# 348   CONTROL      IMG_8740.png      CONTROL           1.0
# 349   CONTROL      IMG_8741.png      CONTROL           0.0
# 350   CONTROL      IMG_8742.png      CONTROL           0.0
# 351   CONTROL      IMG_8744.png      CONTROL           1.0
# 352   CONTROL      IMG_8745.png      CONTROL           0.0
# 353   CONTROL      IMG_8746.png      NON DRR           1.0
# 354   CONTROL      IMG_8747.png      CONTROL           0.0
# 355   CONTROL      IMG_8748.png      NON DRR           2.0
# 356   CONTROL      IMG_8749.png      CONTROL           1.0
# 357   CONTROL      IMG_8750.png      CONTROL           0.0
# 358   CONTROL      IMG_8751.png      NON DRR           4.0
# 359   CONTROL      IMG_8752.png      CONTROL           0.0
# 360   CONTROL      IMG_8753.png      NON DRR           3.0
# 361   CONTROL      IMG_8754.png      CONTROL           0.0
# 362   CONTROL      IMG_8755.png      CONTROL           0.0
# 363   CONTROL      IMG_8756.png      CONTROL           0.0
# 364   CONTROL      IMG_8757.png      CONTROL           0.0
# 365   CONTROL      IMG_8758.png      CONTROL           0.0
# 366   CONTROL      IMG_8759.png      CONTROL           0.0
# 367   CONTROL      IMG_8760.png      CONTROL           0.0
# 368   CONTROL      IMG_8761.png      CONTROL           0.0
# 369   CONTROL      IMG_8762.png      CONTROL           0.0
# 370   CONTROL      IMG_8763.png      CONTROL           0.0
# 371   CONTROL      IMG_8764.png      CONTROL           0.0
# 372   CONTROL      IMG_8765.png      CONTROL           0.0
# 373   CONTROL      IMG_8766.png      NON DRR           1.0
# 374   CONTROL      IMG_8767.png      CONTROL           0.0
# 375   CONTROL      IMG_8768.png      CONTROL           0.0
# 376   CONTROL      IMG_8769.png      CONTROL           0.0
# 377   CONTROL      IMG_8770.png      CONTROL           0.0
# 378   CONTROL      IMG_8771.png      CONTROL           0.0
# 379   CONTROL      IMG_8772.png      CONTROL           0.0
# 380   CONTROL      IMG_8773.png      CONTROL           0.0
# 381   CONTROL      IMG_8774.png      CONTROL           0.0
# 382   CONTROL      IMG_8775.png      CONTROL           0.0
# 383   CONTROL      IMG_8776.png      CONTROL           0.0
# 384   CONTROL      IMG_8777.png      CONTROL           0.0
# 385   CONTROL      IMG_8778.png      CONTROL           0.0
# 386   CONTROL      IMG_8779.png      CONTROL           1.0
# 387   CONTROL      IMG_8780.png      CONTROL           0.0
# 388   CONTROL      IMG_8781.png      CONTROL           0.0
# 389   CONTROL      IMG_8782.png      CONTROL           0.0
# 390   CONTROL      IMG_8783.png      NON DRR           1.0
# 391   CONTROL      IMG_8784.png      CONTROL           0.0
# 392   CONTROL      IMG_8785.png      CONTROL           0.0
# 393   CONTROL      IMG_8786.png      CONTROL           0.0
# 394   CONTROL      IMG_8787.png      CONTROL           0.0
# 395   CONTROL      IMG_8788.png      CONTROL           0.0
# 396   CONTROL      IMG_8789.png      CONTROL           0.0
# 397   CONTROL      IMG_8790.png      CONTROL           0.0
# 398   CONTROL      IMG_8791.png      CONTROL           0.0
# 399   CONTROL      IMG_8792.png      CONTROL           0.0
# 400   CONTROL      IMG_8793.png      CONTROL           0.0
# 401   CONTROL      IMG_8794.png      CONTROL           0.0
# 402   CONTROL      IMG_8795.png      CONTROL           0.0
# 403   CONTROL      IMG_8796.png      CONTROL           0.0
# 404   CONTROL      IMG_8797.png      CONTROL           0.0
# 405   CONTROL      IMG_8798.png      CONTROL           0.0
# 406   CONTROL      IMG_8799.png      CONTROL           0.0
# 407   CONTROL      IMG_8800.png      CONTROL           0.0
# 408   CONTROL      IMG_8801.png      CONTROL           0.0
# 409   CONTROL      IMG_8802.png      CONTROL           0.0
# 410   CONTROL      IMG_8803.png      CONTROL           0.0
# 411   CONTROL      IMG_8804.png      CONTROL           0.0
# 412   CONTROL      IMG_8805.png      CONTROL           0.0
# 413   CONTROL      IMG_8806.png      CONTROL           0.0
# 414   CONTROL      IMG_8807.png      CONTROL           0.0
# 415   CONTROL      IMG_8808.png      CONTROL           0.0
# 416   CONTROL      IMG_8809.png      CONTROL           1.0
# 417   CONTROL      IMG_8810.png      CONTROL           0.0
# 418   CONTROL      IMG_8811.png      CONTROL           0.0
# 419   CONTROL      IMG_8812.png      CONTROL           0.0
# 420   CONTROL      IMG_8813.png      CONTROL           0.0
# 421   CONTROL      IMG_8814.png      CONTROL           0.0
# 422   CONTROL      IMG_8815.png      CONTROL           0.0
# 423   CONTROL      IMG_8816.png      CONTROL           0.0
# 424   CONTROL      IMG_8817.png      CONTROL           0.0
# 425   CONTROL      IMG_8818.png      CONTROL           0.0
# 426   CONTROL      IMG_8819.png      CONTROL           0.0
# 427   CONTROL      IMG_8820.png      CONTROL           0.0
# 428   CONTROL      IMG_8821.png      CONTROL           0.0
# 429   CONTROL      IMG_8822.png      CONTROL           1.0
# 430   CONTROL      IMG_8823.png      NON DRR           3.0
# 431   CONTROL      IMG_8824.png      CONTROL           0.0
# 432   CONTROL      IMG_8825.png      CONTROL           0.0
# 433   CONTROL      IMG_8826.png      CONTROL           0.0
# 434   CONTROL      IMG_8827.png      CONTROL           0.0
# 435   CONTROL      IMG_8828.png      CONTROL           0.0
# 436   CONTROL      IMG_8829.png      CONTROL           0.0
# 437   CONTROL      IMG_8830.png      CONTROL           0.0
# 438   CONTROL      IMG_8831.png      CONTROL           0.0
# 439   CONTROL      IMG_8832.png      CONTROL           0.0
# 440   CONTROL      IMG_8833.png      CONTROL           0.0
# 441   CONTROL      IMG_8834.png      CONTROL           0.0
# 442   CONTROL      IMG_8835.png      CONTROL           0.0
# 443   CONTROL      IMG_8836.png      CONTROL           0.0
# 444   CONTROL      IMG_8837.png      CONTROL           0.0
# 445   CONTROL      IMG_8838.png      CONTROL           0.0
# 446   CONTROL      IMG_8839.png      CONTROL           0.0
# 447   CONTROL      IMG_8840.png      CONTROL           0.0
# 448   CONTROL      IMG_8841.png      CONTROL           0.0
# 449   CONTROL      IMG_8842.png      CONTROL           0.0
# 450   CONTROL      IMG_8843.png      CONTROL           0.0
# 451   CONTROL      IMG_8844.png      CONTROL           0.0
# 452   CONTROL      IMG_8845.png      CONTROL           1.0
# 453   CONTROL      IMG_8846.png      CONTROL           0.0
# 454   CONTROL      IMG_8847.png      CONTROL           0.0
# 455   CONTROL      IMG_8848.png      CONTROL           0.0
# 456   CONTROL      IMG_8849.png      CONTROL           0.0
# 457   CONTROL      IMG_8850.png      NON DRR           4.0
# 458   CONTROL      IMG_8851.png      NON DRR           3.0
# 459   CONTROL      IMG_8852.png      CONTROL           0.0
# 460   CONTROL      IMG_8853.png      NON DRR           3.0
# 461   CONTROL      IMG_8854.png      CONTROL           0.0
# 462   CONTROL      IMG_8855.png      NON DRR           6.0
# 463   CONTROL      IMG_8856.png      CONTROL           1.0
# 464   CONTROL      IMG_8857.png      CONTROL           1.0
# 465   CONTROL      IMG_8858.png      NON DRR           2.0
# 466   CONTROL      IMG_8859.png      NON DRR           6.0
# 467   CONTROL      IMG_8860.png      CONTROL           0.0
# 468   CONTROL      IMG_8861.png      NON DRR           3.0
# 469   CONTROL      IMG_8862.png      NON DRR           2.0
# 470   CONTROL      IMG_8863.png      NON DRR           5.0
# 471   CONTROL      IMG_8864.png      NON DRR           2.0
# 472   CONTROL      IMG_8865.png      NON DRR           5.0
# 473   CONTROL      IMG_8866.png      NON DRR           5.0
# 474   CONTROL      IMG_8867.png      NON DRR           5.0
# 475   CONTROL      IMG_8868.png      NON DRR           6.0
# 476   CONTROL      IMG_8869.png      NON DRR           6.0
# 477   CONTROL      IMG_8870.png      NON DRR           2.0
# 478   CONTROL      IMG_8871.png      NON DRR           7.0
# 479   CONTROL      IMG_8872.png      NON DRR           5.0
# 480   CONTROL      IMG_8873.png      NON DRR           5.0
# 481   CONTROL      IMG_8874.png      NON DRR           6.0
# 482   CONTROL      IMG_8875.png      NON DRR           5.0
# 483   CONTROL      IMG_8876.png      NON DRR           5.0
# 484   CONTROL      IMG_8877.png      NON DRR           4.0
# 485  PATHOGEN      DSCF0718.png     PATHOGEN           3.0
# 486  PATHOGEN      DSCF0719.png     PATHOGEN           4.0
# 487  PATHOGEN      DSCF0720.png     PATHOGEN           4.0
# 488  PATHOGEN      DSCF0722.png     PATHOGEN           3.0
# 489  PATHOGEN      DSCF0723.png     PATHOGEN           4.0
# 490  PATHOGEN      DSCF0724.png     PATHOGEN           4.0
# 491  PATHOGEN      DSCF0725.png     PATHOGEN           3.0
# 492  PATHOGEN      DSCF0726.png     PATHOGEN           3.0
# 493  PATHOGEN      DSCF0727.png     PATHOGEN           3.0
# 494  PATHOGEN      DSCF0728.png     PATHOGEN           4.0
# 495  PATHOGEN      DSCF0729.png     PATHOGEN           4.0
# 496  PATHOGEN      DSCF0730.png     PATHOGEN           3.0
# 497  PATHOGEN      DSCF0731.png     PATHOGEN           4.0
# 498  PATHOGEN      DSCF0732.png     PATHOGEN           3.0
# 499  PATHOGEN      DSCF0733.png     PATHOGEN           3.0
# 500  PATHOGEN      DSCF0734.png     PATHOGEN           4.0
# 501  PATHOGEN      DSCF0735.png     PATHOGEN           4.0
# 502  PATHOGEN      DSCF0736.png     PATHOGEN           3.0
# 503  PATHOGEN      DSCF0737.png     PATHOGEN           4.0
# 504  PATHOGEN      DSCF0739.png     PATHOGEN           3.0
# 505  PATHOGEN      DSCF0742.png     PATHOGEN           3.0
# 506  PATHOGEN      DSCF0743.png     PATHOGEN           3.0
# 507  PATHOGEN      DSCF0744.png     PATHOGEN           4.0
# 508  PATHOGEN      DSCF0745.png     PATHOGEN           3.0
# 509  PATHOGEN      DSCF0746.png     PATHOGEN           3.0
# 510  PATHOGEN      DSCF0747.png     PATHOGEN           4.0
# 511  PATHOGEN      DSCF0748.png     PATHOGEN           3.0
# 512  PATHOGEN      DSCF0749.png     PATHOGEN           4.0
# 513  PATHOGEN      DSCF0750.png     PATHOGEN           3.0
# 514  PATHOGEN      DSCF0751.png     PATHOGEN           4.0
# 515  PATHOGEN      DSCF0752.png     PATHOGEN           4.0
# 516  PATHOGEN      DSCF0753.png     PATHOGEN           4.0
# 517  PATHOGEN      DSCF0754.png     PATHOGEN           4.0
# 518  PATHOGEN      DSCF0755.png      CONTROL           1.0
# 519  PATHOGEN      DSCF0756.png     PATHOGEN           4.0
# 520  PATHOGEN      DSCF0757.png     PATHOGEN           3.0
# 521  PATHOGEN      DSCF0758.png     PATHOGEN           4.0
# 522  PATHOGEN      DSCF0759.png     PATHOGEN           4.0
# 523  PATHOGEN      DSCF0760.png     PATHOGEN           3.0
# 524  PATHOGEN      DSCF0761.png     PATHOGEN           3.0
# 525  PATHOGEN      DSCF0762.png     PATHOGEN           4.0
# 526  PATHOGEN      DSCF0763.png     PATHOGEN           3.0
# 527  PATHOGEN      DSCF0764.png     PATHOGEN           3.0
# 528  PATHOGEN      DSCF0765.png     PATHOGEN           4.0
# 529  PATHOGEN      DSCF0766.png      CONTROL           1.0
# 530  PATHOGEN      DSCF0767.png     PATHOGEN           4.0
# 531  PATHOGEN      DSCF0768.png     PATHOGEN           3.0
# 532  PATHOGEN      DSCF0769.png     PATHOGEN           4.0
# 533  PATHOGEN      DSCF0770.png     PATHOGEN           4.0
# 534  PATHOGEN      DSCF0771.png     PATHOGEN           3.0
# 535  PATHOGEN      DSCF0772.png      CONTROL           4.0
# 536  PATHOGEN      DSCF0773.png      CONTROL           0.0
# 537  PATHOGEN      DSCF0774.png      CONTROL           0.0
# 538  PATHOGEN      DSCF0775.png     PATHOGEN           3.0
# 539  PATHOGEN      DSCF0776.png     PATHOGEN           4.0
# 540  PATHOGEN      DSCF0777.png     PATHOGEN           3.0
# 541  PATHOGEN      DSCF0778.png     PATHOGEN           1.0
# 542  PATHOGEN      DSCF0779.png     PATHOGEN           4.0
# 543  PATHOGEN      DSCF0780.png     PATHOGEN           3.0
# 544  PATHOGEN      DSCF0781.png     PATHOGEN           4.0
# 545  PATHOGEN      DSCF0782.png     PATHOGEN           4.0
# 546  PATHOGEN      DSCF0783.png     PATHOGEN           4.0
# 547  PATHOGEN      DSCF0784.png     PATHOGEN           4.0
# 548  PATHOGEN      DSCF0785.png     PATHOGEN           4.0
# 549  PATHOGEN      DSCF0786.png     PATHOGEN           4.0
# 550  PATHOGEN      DSCF0787.png     PATHOGEN           3.0
# 551  PATHOGEN      DSCF0788.png     PATHOGEN           3.0
# 552  PATHOGEN      DSCF0789.png     PATHOGEN           3.0
# 553  PATHOGEN      DSCF0790.png     PATHOGEN           4.0
# 554  PATHOGEN      DSCF0791.png     PATHOGEN           4.0
# 555  PATHOGEN      DSCF0792.png     PATHOGEN           3.0
# 556  PATHOGEN      DSCF0793.png     PATHOGEN           4.0
# 557  PATHOGEN      DSCF0794.png     PATHOGEN           3.0
# 558  PATHOGEN      DSCF0795.png     PATHOGEN           3.0
# 559  PATHOGEN      DSCF0796.png      CONTROL           0.0
# 560  PATHOGEN      DSCF0797.png      CONTROL           1.0
# 561  PATHOGEN      DSCF0798.png     PATHOGEN           4.0
# 562  PATHOGEN      DSCF0799.png     PATHOGEN           4.0
# 563  PATHOGEN      DSCF0800.png     PATHOGEN           3.0
# 564  PATHOGEN      DSCF0801.png     PATHOGEN           4.0
# 565  PATHOGEN      DSCF0802.png     PATHOGEN           4.0
# 566  PATHOGEN      DSCF0803.png     PATHOGEN           4.0
# 567  PATHOGEN      DSCF0804.png     PATHOGEN           4.0
# 568  PATHOGEN      DSCF0805.png     PATHOGEN           3.0
# 569  PATHOGEN      DSCF0806.png     PATHOGEN           4.0
# 570  PATHOGEN      DSCF0807.png     PATHOGEN           4.0
# 571  PATHOGEN      DSCF0808.png     PATHOGEN           4.0
# 572  PATHOGEN      DSCF0809.png     PATHOGEN           4.0
# 573  PATHOGEN      DSCF0810.png     PATHOGEN           3.0
# 574  PATHOGEN      DSCF0811.png     PATHOGEN           4.0
# 575  PATHOGEN      DSCF0812.png     PATHOGEN           3.0
# 576  PATHOGEN      DSCF0813.png     PATHOGEN           4.0
# 577  PATHOGEN      DSCF0814.png     PATHOGEN           3.0
# 578  PATHOGEN      DSCF0815.png     PATHOGEN           4.0
# 579  PATHOGEN      DSCF0816.png     PATHOGEN           4.0
# 580  PATHOGEN      DSCF0817.png     PATHOGEN           4.0
# 581  PATHOGEN      DSCF0818.png     PATHOGEN           3.0
# 582  PATHOGEN      DSCF0819.png     PATHOGEN           3.0
# 583  PATHOGEN       ICC1023.png     PATHOGEN           5.0
# 584  PATHOGEN      ICC10236.png     PATHOGEN           4.0
# 585  PATHOGEN      ICC10334.png      NON DRR           6.0
# 586  PATHOGEN  ICC10375 (3).png     PATHOGEN           1.0
# 587  PATHOGEN      ICC10382.png      NON DRR           3.0
# 588  PATHOGEN      ICC10384.png     PATHOGEN           5.0
# 589  PATHOGEN      ICC10394.png      NON DRR           6.0
# 590  PATHOGEN      ICC10455.png     PATHOGEN           5.0
# 591  PATHOGEN      ICC10465.png     PATHOGEN           5.0
# 592  PATHOGEN      ICC10492.png      NON DRR           6.0
# 593  PATHOGEN      ICC10538.png      NON DRR           6.0
# 594  PATHOGEN      ICC10556.png     PATHOGEN           5.0
# 595  PATHOGEN      ICC10563.png     PATHOGEN           5.0
# 596  PATHOGEN      ICC10599.png     PATHOGEN           4.0
# 597  PATHOGEN      ICC10616.png     PATHOGEN           5.0
# 598  PATHOGEN      ICC11611.png     PATHOGEN           4.0
# 599  PATHOGEN       ICC1196.png     PATHOGEN           3.0
# 600  PATHOGEN         ICC12.png     PATHOGEN           4.0
# 601  PATHOGEN       ICC1201.png     PATHOGEN           4.0
# 602  PATHOGEN       ICC1202.png      NON DRR           5.0
# 603  PATHOGEN       ICC1204.png     PATHOGEN           3.0
# 604  PATHOGEN       ICC1205.png     PATHOGEN           4.0
# 605  PATHOGEN       ICC1214.png     PATHOGEN           4.0
# 606  PATHOGEN       ICC1228.png     PATHOGEN           4.0
# 607  PATHOGEN       ICC1229.png     PATHOGEN           3.0
# 608  PATHOGEN       ICC1232.png     PATHOGEN           4.0
# 609  PATHOGEN       ICC1234.png     PATHOGEN           5.0
# 610  PATHOGEN      ICC12369.png      NON DRR           6.0
# 611  PATHOGEN       ICC1237.png     PATHOGEN           4.0
# 612  PATHOGEN      ICC12377.png      NON DRR           6.0
# 613  PATHOGEN       ICC1240.png     PATHOGEN           4.0
# 614  PATHOGEN      ICC12438.png     PATHOGEN           5.0
# 615  PATHOGEN      ICC12441.png      NON DRR           6.0
# 616  PATHOGEN      ICC12442.png      NON DRR           6.0
# 617  PATHOGEN      ICC12443.png     PATHOGEN           5.0
# 618  PATHOGEN      ICC12445.png     PATHOGEN           4.0
# 619  PATHOGEN       ICC1246.png     PATHOGEN           4.0
# 620  PATHOGEN      ICC12466.png      NON DRR           6.0
# 621  PATHOGEN       ICC1250.png     PATHOGEN           4.0
# 622  PATHOGEN       ICC1265.png     PATHOGEN           4.0
# 623  PATHOGEN   ICC1271 (3).png      NON DRR           6.0
# 624  PATHOGEN       ICC1271.png     PATHOGEN           5.0
# 625  PATHOGEN       ICC1272.png     PATHOGEN           3.0
# 626  PATHOGEN       ICC1285.png     PATHOGEN           2.0
# 627  PATHOGEN       ICC1291.png     PATHOGEN           4.0
# 628  PATHOGEN       ICC1295.png     PATHOGEN           4.0
# 629  PATHOGEN       ICC1296.png     PATHOGEN           4.0
# 630  PATHOGEN       ICC1297.png     PATHOGEN           4.0
# 631  PATHOGEN       ICC1298.png     PATHOGEN           5.0
# 632  PATHOGEN       ICC1315.png     PATHOGEN           4.0
# 633  PATHOGEN       ICC1337.png     PATHOGEN           4.0
# 634  PATHOGEN       ICC1338.png     PATHOGEN           4.0
# 635  PATHOGEN       ICC1356.png     PATHOGEN           3.0
# 636  PATHOGEN      ICC1360_.png     PATHOGEN           4.0
# 637  PATHOGEN       ICC1392.png     PATHOGEN           4.0
# 638  PATHOGEN      ICC13939.png      NON DRR           6.0
# 639  PATHOGEN       ICC1397.png     PATHOGEN           3.0
# 640  PATHOGEN       ICC1398.png     PATHOGEN           2.0
# 641  PATHOGEN       ICC1402.png     PATHOGEN           4.0
# 642  PATHOGEN       ICC1419.png     PATHOGEN           4.0
# 643  PATHOGEN       ICC1422.png     PATHOGEN           4.0
# 644  PATHOGEN       ICC1424.png     PATHOGEN           3.0
# 645  PATHOGEN       ICC1431.png     PATHOGEN           3.0
# 646  PATHOGEN      ICC14401.png     PATHOGEN           5.0
# 647  PATHOGEN      ICC14410.png      NON DRR           6.0
# 648  PATHOGEN       ICC1443.png     PATHOGEN           3.0
# 649  PATHOGEN      ICC14431.png     PATHOGEN           4.0
# 650  PATHOGEN       ICC1445.png     PATHOGEN           4.0
# 651  PATHOGEN       ICC1449.png     PATHOGEN           3.0
# 652  PATHOGEN       ICC1498.png     PATHOGEN           4.0
# 653  PATHOGEN       ICC1499.png     PATHOGEN           3.0
# 654  PATHOGEN       ICC1505.png     PATHOGEN           4.0
# 655  PATHOGEN       ICC1507.png     PATHOGEN           2.0
# 656  PATHOGEN       ICC1510.png     PATHOGEN           4.0
# 657  PATHOGEN       ICC1520.png     PATHOGEN           3.0
# 658  PATHOGEN       ICC1553.png     PATHOGEN           3.0
# 659  PATHOGEN       ICC1560.png     PATHOGEN           4.0
# 660  PATHOGEN       ICC1569.png     PATHOGEN           4.0
# 661  PATHOGEN       ICC1579.png     PATHOGEN           3.0
# 662  PATHOGEN       ICC1594.png     PATHOGEN           4.0
# 663  PATHOGEN       ICC1599.png     PATHOGEN           4.0
# 664  PATHOGEN       ICC1600.png     PATHOGEN           4.0
# 665  PATHOGEN       ICC1609.png     PATHOGEN           5.0
# 666  PATHOGEN       ICC1611.png     PATHOGEN           3.0
# 667  PATHOGEN       ICC1616.png     PATHOGEN           3.0
# 668  PATHOGEN       ICC1629.png     PATHOGEN           4.0
# 669  PATHOGEN        ICC170.png     PATHOGEN           4.0
# 670  PATHOGEN         ICC18.png     PATHOGEN           5.0
# 671  PATHOGEN        ICC181.png     PATHOGEN           5.0
# 672  PATHOGEN        ICC182.png     PATHOGEN           4.0
# 673  PATHOGEN       ICC1901.png     PATHOGEN           5.0
# 674  PATHOGEN       ICC1925.png      NON DRR           6.0
# 675  PATHOGEN       ICC2039.png     PATHOGEN           5.0
# 676  PATHOGEN        ICC209.png     PATHOGEN           4.0
# 677  PATHOGEN        ICC216.png     PATHOGEN           5.0
# 678  PATHOGEN       ICC2165.png      NON DRR           6.0
# 679  PATHOGEN       ICC2237.png     PATHOGEN           5.0
# 680  PATHOGEN        ICC240.png     PATHOGEN           5.0
# 681  PATHOGEN   ICC2430 (2).png     PATHOGEN           5.0
# 682  PATHOGEN       ICC2430.png      NON DRR           6.0
# 683  PATHOGEN       ICC2461.png      NON DRR           6.0
# 684  PATHOGEN        ICC250.png     PATHOGEN           5.0
# 685  PATHOGEN        ICC253.png     PATHOGEN           4.0
# 686  PATHOGEN       ICC2616.png     PATHOGEN           5.0
# 687  PATHOGEN        ICC265.png     PATHOGEN           4.0
# 688  PATHOGEN       ICC2858.png     PATHOGEN           5.0
# 689  PATHOGEN       ICC2883.png      NON DRR           6.0
# 690  PATHOGEN       ICC3392.png     PATHOGEN           5.0
# 691  PATHOGEN       ICC3448.png      NON DRR           6.0
# 692  PATHOGEN       ICC3562.png      NON DRR           6.0
# 693  PATHOGEN       ICC3573.png      NON DRR           6.0
# 694  PATHOGEN       ICC3597.png     PATHOGEN           5.0
# 695  PATHOGEN       ICC3599.png      NON DRR           6.0
# 696  PATHOGEN       ICC3606.png      NON DRR           6.0
# 697  PATHOGEN       ICC3650.png     PATHOGEN           6.0
# 698  PATHOGEN       ICC3737.png     PATHOGEN           5.0
# 699  PATHOGEN       ICC3739.png      NON DRR           6.0
# 700  PATHOGEN       ICC3742.png     PATHOGEN           5.0
# 701  PATHOGEN       ICC3854.png      NON DRR           6.0
# 702  PATHOGEN       ICC3855.png     PATHOGEN           4.0
# 703  PATHOGEN       ICC4066.png      NON DRR           6.0
# 704  PATHOGEN        ICC413.png     PATHOGEN           5.0
# 705  PATHOGEN       ICC4200.png     PATHOGEN           5.0
# 706  PATHOGEN         ICC43.png     PATHOGEN           4.0
# 707  PATHOGEN       ICC4485.png     PATHOGEN           5.0
# 708  PATHOGEN       ICC4490.png      NON DRR           6.0
# 709  PATHOGEN       ICC4509.png      NON DRR           6.0
# 710  PATHOGEN       ICC4529.png      NON DRR           6.0
# 711  PATHOGEN        ICC454.png     PATHOGEN           4.0
# 712  PATHOGEN       ICC4640.png      NON DRR           6.0
# 713  PATHOGEN   ICC4751 (2).png      NON DRR           6.0
# 714  PATHOGEN       ICC4751.png      NON DRR           6.0
# 715  PATHOGEN       ICC4785.png      NON DRR           6.0
# 716  PATHOGEN       ICC4787.png      NON DRR           5.0
# 717  PATHOGEN       ICC4827.png      NON DRR           6.0
# 718  PATHOGEN       ICC4847.png      NON DRR           6.0
# 719  PATHOGEN       ICC4850.png      NON DRR           6.0
# 720  PATHOGEN       ICC4919.png     PATHOGEN           4.0
# 721  PATHOGEN       ICC4940.png      NON DRR           6.0
# 722  PATHOGEN       ICC4974.png      NON DRR           6.0
# 723  PATHOGEN       ICC4987.png      NON DRR           6.0
# 724  PATHOGEN       ICC5004.png      NON DRR           6.0
# 725  PATHOGEN       ICC5006.png      NON DRR           6.0
# 726  PATHOGEN       ICC5024.png      NON DRR           6.0
# 727  PATHOGEN       ICC5103.png      NON DRR           6.0
# 728  PATHOGEN       ICC5105.png      NON DRR           6.0
# 729  PATHOGEN       ICC5618.png      NON DRR           6.0
# 730  PATHOGEN       ICC5726.png     PATHOGEN           5.0
# 731  PATHOGEN       ICC5762.png     PATHOGEN           4.0
# 732  PATHOGEN       ICC5778.png     PATHOGEN           4.0
# 733  PATHOGEN       ICC5780.png     PATHOGEN           4.0
# 734  PATHOGEN       ICC5811.png     PATHOGEN           3.0
# 735  PATHOGEN       ICC5915.png     PATHOGEN           3.0
# 736  PATHOGEN       ICC5923.png     PATHOGEN           4.0
# 737  PATHOGEN        ICC595.png     PATHOGEN           4.0
# 738  PATHOGEN        ICC599.png     PATHOGEN           5.0
# 739  PATHOGEN        ICC607.png     PATHOGEN           5.0
# 740  PATHOGEN       ICC6295.png     PATHOGEN           4.0
# 741  PATHOGEN       ICC6347.png     PATHOGEN           3.0
# 742  PATHOGEN       ICC6359.png     PATHOGEN           5.0
# 743  PATHOGEN       ICC6384.png     PATHOGEN           4.0
# 744  PATHOGEN         ICC64.png     PATHOGEN           4.0
# 745  PATHOGEN       ICC6401.png     PATHOGEN           4.0
# 746  PATHOGEN       ICC6410.png     PATHOGEN           3.0
# 747  PATHOGEN       ICC6419.png     PATHOGEN           3.0
# 748  PATHOGEN       ICC6423.png     PATHOGEN           4.0
# 749  PATHOGEN       ICC6438.png     PATHOGEN           4.0
# 750  PATHOGEN       ICC6441.png     PATHOGEN           4.0
# 751  PATHOGEN       ICC6445.png     PATHOGEN           3.0
# 752  PATHOGEN       ICC6448.png     PATHOGEN           4.0
# 753  PATHOGEN       ICC6452.png     PATHOGEN           2.0
# 754  PATHOGEN       ICC6480.png      NON DRR           6.0
# 755  PATHOGEN       ICC6483.png     PATHOGEN           4.0
# 756  PATHOGEN       ICC6492.png     PATHOGEN           4.0
# 757  PATHOGEN       ICC6497.png     PATHOGEN           4.0
# 758  PATHOGEN       ICC6498.png     PATHOGEN           4.0
# 759  PATHOGEN       ICC6504.png     PATHOGEN           4.0
# 760  PATHOGEN       ICC6510.png     PATHOGEN           3.0
# 761  PATHOGEN       ICC6537.png     PATHOGEN           3.0
# 762  PATHOGEN       ICC6551.png     PATHOGEN           3.0
# 763  PATHOGEN       ICC6566.png     PATHOGEN           3.0
# 764  PATHOGEN       ICC6571.png     PATHOGEN           4.0
# 765  PATHOGEN       ICC6579.png     PATHOGEN           3.0
# 766  PATHOGEN       ICC6616.png     PATHOGEN           4.0
# 767  PATHOGEN       ICC6659.png     PATHOGEN           4.0
# 768  PATHOGEN       ICC6661.png     PATHOGEN           4.0
# 769  PATHOGEN       ICC6671.png     PATHOGEN           4.0
# 770  PATHOGEN       ICC6679.png     PATHOGEN           5.0
# 771  PATHOGEN       ICC6723.png     PATHOGEN           4.0
# 772  PATHOGEN       ICC6731.png     PATHOGEN           4.0
# 773  PATHOGEN       ICC6732.png     PATHOGEN           4.0
# 774  PATHOGEN       ICC6743.png      NON DRR           6.0
# 775  PATHOGEN       ICC6756.png      NON DRR           6.0
# 776  PATHOGEN       ICC6777.png     PATHOGEN           2.0
# 777  PATHOGEN       ICC6796.png     PATHOGEN           4.0
# 778  PATHOGEN         ICC68.png     PATHOGEN           5.0
# 779  PATHOGEN       ICC6801.png     PATHOGEN           4.0
# 780  PATHOGEN       ICC6803.png      NON DRR           5.0
# 781  PATHOGEN       ICC6804.png     PATHOGEN           3.0
# 782  PATHOGEN       ICC6811.png     PATHOGEN           4.0
# 783  PATHOGEN       ICC6815.png      NON DRR           6.0
# 784  PATHOGEN       ICC6817.png     PATHOGEN           5.0
# 785  PATHOGEN       ICC6818.png     PATHOGEN           5.0
# 786  PATHOGEN       ICC6819.png     PATHOGEN           4.0
# 787  PATHOGEN       ICC6821.png     PATHOGEN           5.0
# 788  PATHOGEN       ICC6822.png     PATHOGEN           5.0
# 789  PATHOGEN       ICC6843.png     PATHOGEN           5.0
# 790  PATHOGEN       ICC6858.png     PATHOGEN           5.0
# 791  PATHOGEN       ICC6876.png      NON DRR           6.0
# 792  PATHOGEN       ICC6877.png     PATHOGEN           4.0
# 793  PATHOGEN       ICC6879.png      NON DRR           6.0
# 794  PATHOGEN       ICC6880.png      NON DRR           6.0
# 795  PATHOGEN       ICC6881.png     PATHOGEN           4.0
# 796  PATHOGEN       ICC6883.png      NON DRR           6.0
# 797  PATHOGEN       ICC6885.png      NON DRR           6.0
# 798  PATHOGEN       ICC6903.png     PATHOGEN           4.0
# 799  PATHOGEN       ICC6906.png     PATHOGEN           5.0
# 800  PATHOGEN       ICC6914.png      NON DRR           6.0
# 801  PATHOGEN       ICC6916.png     PATHOGEN           5.0
# 802  PATHOGEN       ICC6917.png      NON DRR           6.0
# 803  PATHOGEN       ICC6919.png     PATHOGEN           3.0
# 804  PATHOGEN       ICC6921.png     PATHOGEN           3.0
# 805  PATHOGEN       ICC6923.png      NON DRR           6.0
# 806  PATHOGEN       ICC6924.png      NON DRR           6.0
# 807  PATHOGEN       ICC6926.png     PATHOGEN           5.0
# 808  PATHOGEN       ICC6933.png      NON DRR           5.0
# 809  PATHOGEN       ICC6939.png      NON DRR           6.0
# 810  PATHOGEN       ICC6944.png     PATHOGEN           4.0
# 811  PATHOGEN       ICC6949.png      NON DRR           4.0
# 812  PATHOGEN       ICC6953.png      NON DRR           6.0
# 813  PATHOGEN       ICC6962.png     PATHOGEN           5.0
# 814  PATHOGEN       ICC6974.png      NON DRR           5.0
# 815  PATHOGEN       ICC6982.png      NON DRR           4.0
# 816  PATHOGEN       ICC6983.png      NON DRR           5.0
# 817  PATHOGEN       ICC6984.png      NON DRR           6.0
# 818  PATHOGEN       ICC6999.png      NON DRR           4.0
# 819  PATHOGEN       ICC7000.png     PATHOGEN           4.0
# 820  PATHOGEN       ICC7005.png      NON DRR           5.0
# 821  PATHOGEN       ICC7014.png     PATHOGEN           5.0
# 822  PATHOGEN       ICC7144.png     PATHOGEN           4.0
# 823  PATHOGEN       ICC7172.png     PATHOGEN           4.0
# 824  PATHOGEN       ICC7200.png     PATHOGEN           4.0
# 825  PATHOGEN       ICC7201.png     PATHOGEN           3.0
# 826  PATHOGEN       ICC7207.png     PATHOGEN           3.0
# 827  PATHOGEN       ICC7401.png     PATHOGEN           5.0
# 828  PATHOGEN       ICC7856.png     PATHOGEN           4.0
# 829  PATHOGEN        ICC860.png      NON DRR           6.0
# 830  PATHOGEN        ICC880.png      NON DRR           6.0
# 831  PATHOGEN       ICC8818.png      NON DRR           6.0
# 832  PATHOGEN       ICC8872.png      NON DRR           6.0
# 833  PATHOGEN       ICC8933.png      NON DRR           6.0
# 834  PATHOGEN       ICC8967.png      NON DRR           6.0
# 835  PATHOGEN       ICC8977.png      NON DRR           6.0
# 836  PATHOGEN       ICC8980.png      NON DRR           6.0
# 837  PATHOGEN         ICC91.png      NON DRR           6.0
# 838  PATHOGEN       ICC9112.png     PATHOGEN           5.0
# 839  PATHOGEN       ICC9117.png      NON DRR           6.0
# 840  PATHOGEN       ICC9127.png     PATHOGEN           4.0
# 841  PATHOGEN       ICC9143.png     PATHOGEN           4.0
# 842  PATHOGEN       ICC9496.png      NON DRR           4.0
# 843  PATHOGEN       ICC9519.png     PATHOGEN           5.0
# 844  PATHOGEN       ICC9522.png      NON DRR           6.0
# 845  PATHOGEN       ICC9668.png     PATHOGEN           5.0
